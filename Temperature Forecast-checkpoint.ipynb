# %% [markdown]
# # Temperature Forecast Project

# %% [markdown]
# # Project Description

# %% [markdown]
# This data is for the purpose of bias correction of next-day maximum and minimum air temperatures forecast of the LDAPS model operated by the Korea Meteorological Administration over Seoul, South Korea. This data consists of summer data from 2013 to 2017. The input data is largely composed of the LDAPS model's next-day forecast data, in-situ maximum and minimum temperatures of present-day, and geographic auxiliary variables. There are two outputs (i.e. next-day maximum and minimum air temperatures) in this data. Hindcast validation was conducted for the period from 2015 to 2017.

# %% [markdown]
# # Attribute Information:

# %% [markdown]
# 1. station - used weather station number: 1 to 25
# 2. Date - Present day: yyyy-mm-dd ('2013-06-30' to '2017-08-30')
# 3. Present_Tmax - Maximum air temperature between 0 and 21 h on the present day (Â°C): 20 to 37.6
# 4. Present_Tmin - Minimum air temperature between 0 and 21 h on the present day (Â°C): 11.3 to 29.9
# 5. LDAPS_RHmin - LDAPS model forecast of next-day minimum relative humidity (%): 19.8 to 98.5
# 6. LDAPS_RHmax - LDAPS model forecast of next-day maximum relative humidity (%): 58.9 to 100
# 7. LDAPS_Tmax_lapse - LDAPS model forecast of next-day maximum air temperature applied lapse rate (Â°C): 17.6 to 38.5
# 8. LDAPS_Tmin_lapse - LDAPS model forecast of next-day minimum air temperature applied lapse rate (Â°C): 14.3 to 29.6
# 9. LDAPS_WS - LDAPS model forecast of next-day average wind speed (m/s): 2.9 to 21.9
# 10. LDAPS_LH - LDAPS model forecast of next-day average latent heat flux (W/m2): -13.6 to 213.4
# 11. LDAPS_CC1 - LDAPS model forecast of next-day 1st 6-hour split average cloud cover (0-5 h) (%): 0 to 0.97
# 12. LDAPS_CC2 - LDAPS model forecast of next-day 2nd 6-hour split average cloud cover (6-11 h) (%): 0 to 0.97
# 13. LDAPS_CC3 - LDAPS model forecast of next-day 3rd 6-hour split average cloud cover (12-17 h) (%): 0 to 0.98
# 14. LDAPS_CC4 - LDAPS model forecast of next-day 4th 6-hour split average cloud cover (18-23 h) (%): 0 to 0.97
# 15. LDAPS_PPT1 - LDAPS model forecast of next-day 1st 6-hour split average precipitation (0-5 h) (%): 0 to 23.7
# 16. LDAPS_PPT2 - LDAPS model forecast of next-day 2nd 6-hour split average precipitation (6-11 h) (%): 0 to 21.6
# 17. LDAPS_PPT3 - LDAPS model forecast of next-day 3rd 6-hour split average precipitation (12-17 h) (%): 0 to 15.8
# 18. LDAPS_PPT4 - LDAPS model forecast of next-day 4th 6-hour split average precipitation (18-23 h) (%): 0 to 16.7
# 19. lat - Latitude (Â°): 37.456 to 37.645
# 20. lon - Longitude (Â°): 126.826 to 127.135
# 21. DEM - Elevation (m): 12.4 to 212.3
# 22. Slope - Slope (Â°): 0.1 to 5.2
# 23. Solar radiation - Daily incoming solar radiation (wh/m2): 4329.5 to 5992.9
# 24. Next_Tmax - The next-day maximum air temperature (Â°C): 17.4 to 38.9
# 25. Next_Tmin - The next-day minimum air temperature (Â°C): 11.3 to 29.8T

# %% [markdown]
# # Importing Necesssary Libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # importing Dataset

# %%
df= pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Temperature%20Forecast/temperature.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.tail()
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# ...

# %% [markdown]
# # First doing a model for maximum temperature

# %%
df.shape
# Out:
# (7752, 25)

# %% [markdown]
# As we can see that there are 7752 rows and 25 columns, out of which one is target variable and the rest our independent variable, as we have to build a model for minimum temp, and max.temp, as in both the cases the target variable is in continuous data, so it will be a regression problem.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['station',
#  'Date',
#  'Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation',
#  'Next_Tmax',
#  'Next_Tmin']

# %%
#checking the types of the columns
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# as we can= observed that there are two types of datatypes, object and float present in the dataset, But as we can see that the date column is in a object datatype, so first we have to convert it in date type format, so that it will be understandble for our model.

# %%
#converting date into date type object
df['Date']=pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# station                    float64
# Date                datetime64[ns]
# Present_Tmax               float64
# Present_Tmin               float64
# LDAPS_RHmin                float64
# LDAPS_RHmax                float64
# LDAPS_Tmax_lapse           float64
# LDAPS_Tmin_lapse           float64
# LDAPS_WS                   float64
# LDAPS_LH                   float64
# LDAPS_CC1                  float64
# LDAPS_CC2                  float64
# LDAPS_CC3                  float64
# LDAPS_CC4                  float64
# LDAPS_PPT1                 float64
# LDAPS_PPT2                 float64
# LDAPS_PPT3                 float64
# LDAPS_PPT4                 float64
# lat                        float64
# lon                        float64
# DEM                        float64
# Slope                      float64
# Solar radiation            float64
# Next_Tmax                  float64
# Next_Tmin                  float64
# dtype: object

# %%
df.dtypes
# Out:
# station                    float64
# Date                datetime64[ns]
# Present_Tmax               float64
# Present_Tmin               float64
# LDAPS_RHmin                float64
# LDAPS_RHmax                float64
# LDAPS_Tmax_lapse           float64
# LDAPS_Tmin_lapse           float64
# LDAPS_WS                   float64
# LDAPS_LH                   float64
# LDAPS_CC1                  float64
# LDAPS_CC2                  float64
# LDAPS_CC3                  float64
# LDAPS_CC4                  float64
# LDAPS_PPT1                 float64
# LDAPS_PPT2                 float64
# LDAPS_PPT3                 float64
# LDAPS_PPT4                 float64
# lat                        float64
# lon                        float64
# DEM                        float64
# Slope                      float64
# Solar radiation            float64
# Next_Tmax                  float64
# Next_Tmin                  float64
# dtype: object

# %% [markdown]
# As we can see that we change the datatype of the date column. now separating the date, month and year.

# %%
# Now Seperating date and month
df['Year']= df['Date'].dt.year
df["Month"] = df["Date"].dt.month
df["Day"] = df["Date"].dt.day

# %%
#drop  the original date column
df.drop('Date', axis=1, inplace=True)

# %%
df
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
# 7750      NaN          20.0          11.3    19.794666    58.936283
# 7751      NaN          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# ...

# %%
df.dtypes
# Out:
# station             float64
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# Year                float64
# Month               float64
# Day                 float64
# dtype: object

# %% [markdown]
# # Checking the null values

# %%
df.isnull().sum()
# Out:
# station              2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# Year                 2
# Month                2
# Day                  2
# dtype: int64

# %% [markdown]
# As we can see that all the columns have null values in it, now we will remove these null values.

# %%
df.isnull().sum().sum()
# Out:
# 1252

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Present_Tmax      7682 non-null   float64
#  2   Present_Tmin      7682 non-null   float64
#  3   LDAPS_RHmin       7677 non-null   float64
#  4   LDAPS_RHmax       7677 non-null   float64
#  5   LDAPS_Tmax_lapse  7677 non-null   float64
#  6   LDAPS_Tmin_lapse  7677 non-null   float64
#  7   LDAPS_WS          7677 non-null   float64
#  8   LDAPS_LH          7677 non-null   float64
#  9   LDAPS_CC1         7677 non-null   float64
#  10  LDAPS_CC2         7677 non-null   float64
#  11  LDAPS_CC3         7677 non-null   float64
#  12  LDAPS_CC4         7677 non-null   float64
#  13  LDAPS_PPT1        7677 non-null   float64
#  14  LDAPS_PPT2        7677 non-null   float64
#  15  LDAPS_PPT3        7677 non-null   float64
# ...

# %%
# using heatmap to visualize null value
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# From the above heatmap also it is observed that null values are present in almost all the columns.

# %%
#filling the null values from station
df['station']= df['station'].fillna(df['station'].mean())

#filling null values from Present_Tmax
df['Present_Tmax']= df['Present_Tmax'].fillna(df['Present_Tmax'].mean())

#filling null values from present_Tmin
df['Present_Tmin']= df['Present_Tmin'].fillna(df['Present_Tmin'].mean())

#filling null values from LDAPS_RHmin
df['LDAPS_RHmin']= df['LDAPS_RHmin'].fillna(df['LDAPS_RHmin'].mean())

#filling null values from LDAPS_RHmax
df['LDAPS_RHmax']= df['LDAPS_RHmax'].fillna(df['LDAPS_RHmax'].mean())

#filling null values from LDAPS_Tmax_lapse
df['LDAPS_Tmax_lapse']= df['LDAPS_Tmax_lapse'].fillna(df['LDAPS_Tmax_lapse'].mean())

#filling null values from LDAPS_TmIN_lapse
df['LDAPS_Tmin_lapse']= df['LDAPS_Tmin_lapse'].fillna(df['LDAPS_Tmin_lapse'].mean())

#filling null values from LDAPS_WS
df['LDAPS_WS']= df['LDAPS_WS'].fillna(df['LDAPS_WS'].mean())

#filling null values from LDAPS_LH
df['LDAPS_LH']= df['LDAPS_LH'].fillna(df['LDAPS_LH'].mean())

#filling null values from LDAPS_CC1
df['LDAPS_CC1']= df['LDAPS_CC1'].fillna(df['LDAPS_CC1'].mean())

#filling null values from LDAPS_CC2
df['LDAPS_CC2']= df['LDAPS_CC2'].fillna(df['LDAPS_CC2'].mean())

#filling null values from LDAPS_CC3
df['LDAPS_CC3']= df['LDAPS_CC3'].fillna(df['LDAPS_CC3'].mean())

#filling null values from LDAPS_CC4
df['LDAPS_CC4']= df['LDAPS_CC4'].fillna(df['LDAPS_CC4'].mean())

#filling null values from LDAPS_PPT1
df['LDAPS_PPT1']= df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].mean())


#filling null values from LDAPS_PPT2
df['LDAPS_PPT2']= df['LDAPS_PPT2'].fillna(df['LDAPS_PPT2'].mean())

#filling null values from LDAPS_PPT3
df['LDAPS_PPT3']= df['LDAPS_PPT3'].fillna(df['LDAPS_PPT3'].mean())

#filling null values from LDAPS_PPT4
df['LDAPS_PPT4']= df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].mean())

#filling null values from LDAPS_PPT1
df['LDAPS_PPT1']= df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].mean())


#filling null values from Next_Tmax
df['Next_Tmax']= df['Next_Tmax'].fillna(df['Next_Tmax'].mean())


#filling null values from Next_Tmin
df['Next_Tmin']= df['Next_Tmin'].fillna(df['Next_Tmin'].mean())

#filling null values from Next_Tmax
df['Next_Tmax']= df['Next_Tmax'].fillna(df['Next_Tmax'].mean())

#filling null values from Year
df['Year']= df['Year'].fillna(df['Year'].mean())


#filling null values from Month
df['Month']= df['Month'].fillna(df['Month'].mean())

#filling null values from Day
df['Day']= df['Day'].fillna(df['Day'].mean())

# %%
#again checking NUll values
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Year                0
# Month               0
# Day                 0
# dtype: int64

# %%
#visualize it through heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Now as we can see that there are no null values in the the dataset.

# %% [markdown]
# ~Now checking the value counts of each column

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 13.0    312
# 14.0    310
# 24.0    310
# 23.0    310
# 22.0    310
# 21.0    310
# 20.0    310
# 19.0    310
# 18.0    310
# 17.0    310
# 16.0    310
# 15.0    310
# 1.0     310
# 2.0     310
# 12.0    310
# 11.0    310
# 10.0    310
# 9.0     310
# 8.0     310
# 7.0     310
# 6.0     310
# 5.0     310
# 4.0     310
# 3.0     310
# 25.0    310
# Name: station, dtype: int64
#
#
# 31.4    112
# 29.4    111
# 29.1    108
# 29.7    107
# 31.9    105
#        ...
# 36.9      1
# 21.2      1
# 20.1      1
# 36.4      1
# 20.3      1
# Name: Present_Tmax, Length: 168, dtype: int64
#
#
# 24.0    161
# 23.8    153
# 23.1    144
# 23.5    143
# 23.3    142
#        ...
# 13.6      1
# 14.2      1
# 29.1      1
# 29.7      1
# 15.0      1
# Name: Present_Tmin, Length: 156, dtype: int64
#
#
# 56.759372    75
# 77.030350     2
# 98.524734     2
# 19.794666     2
# 51.810596     2
#              ..
# 52.924568     1
# 60.215191     1
# 46.799820     1
# 52.227486     1
# 22.933014     1
# ...

# %%
# checking the unique values in each column
df.nunique().to_frame("No. of unique values")
# Out:
#                   No. of unique values
# station                             25
# Present_Tmax                       168
# Present_Tmin                       156
# LDAPS_RHmin                       7673
# LDAPS_RHmax                       7665
# LDAPS_Tmax_lapse                  7676
# LDAPS_Tmin_lapse                  7676
# LDAPS_WS                          7676
# LDAPS_LH                          7676
# LDAPS_CC1                         7570
# LDAPS_CC2                         7583
# LDAPS_CC3                         7600
# LDAPS_CC4                         7525
# LDAPS_PPT1                        2813
# LDAPS_PPT2                        2511
# LDAPS_PPT3                        2357
# LDAPS_PPT4                        1919
# lat                                 12
# lon                                 25
# DEM                                 25
# Slope                               27
# Solar radiation                   1575
# Next_Tmax                          184
# ...

# %%
#checking duplicates values in the column
print("Total duplicates values are:", df.duplicated().sum())
# Out:
# Total duplicates values are: 0

# %% [markdown]
# As we can see that there are no duplicates values present in the dataset

# %%
#Checking for the whitespaces in the columns
df.loc[df['Next_Tmax']==" "]
# Out:
# Empty DataFrame
# Columns: [station, Present_Tmax, Present_Tmin, LDAPS_RHmin, LDAPS_RHmax, LDAPS_Tmax_lapse, LDAPS_Tmin_lapse, LDAPS_WS, LDAPS_LH, LDAPS_CC1, LDAPS_CC2, LDAPS_CC3, LDAPS_CC4, LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3, LDAPS_PPT4, lat, lon, DEM, Slope, Solar radiation, Next_Tmax, Next_Tmin, Year, Month, Day]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# As we can see that there are no whitespaces present in the dataset

# %% [markdown]
# # Description of dataset

# %%
#statistical summary of the numerical columns
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7752.000000   7752.000000   7752.000000  7752.000000  7752.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.210637      2.956557      2.403036    14.596973     7.157124
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    46.046162    84.316923
# 50%      13.000000     29.900000     23.400000    55.313244    89.699505
# 75%      19.000000     32.000000     24.900000    67.038254    93.704500
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7752.000000       7752.000000  7752.000000  7752.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.932898          2.333973     2.173245    33.567001
# ...

# %% [markdown]
# This gives the statstical summary of the numerical column. The summary of the dataset looks perfect as there are no negative values or invalid values present in the dataset.From the above dataset we can observed the following:
#
# 1) As the value counts of each column is same, it means there are no missing values in the dataset.
# 2) The mean value in the columns LDAPS_RHmin, LDAPS_RHmax, LDAPS_WS, LDAPS_LH, DEM are more than the median value(50%), it means the data is skewed to the right side.
# 3) THere is a difference between 75% and max value it means outliers are present in the dataset.
# 4) We can also observed the standard deviation, minimum value, and 25% value from the above description.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ~Univariate Analysis

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['Present_Tmin'],kde=True,color='g')
plt.subplot(1,2,2)
sns.histplot(df['Present_Tmax'],kde=True,color='b')
plt.show()

# %% [markdown]
# As we can observed that present day minimum Temperature is skewed than present day maximum temperature

# %%
sns.histplot(df['Solar radiation'],kde=True,color='r')
plt.show()

# %% [markdown]
# Solar Radiation is max between 5000 to 6000

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['Next_Tmin'],kde=True,color='y')
plt.subplot(1,2,2)
sns.histplot(df['Next_Tmax'],kde=True,color='b')
plt.show()

# %% [markdown]
# Next day min and max temperature is almost similar.

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=df, x='Year')
plt.xlabel('Year', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.xticks( fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, y='Solar radiation',x='Year',color='b')
plt.show()

# %% [markdown]
# We can observed that solar radiation is almost same for every year.

# %%
#The relationship of Each other.
#plt.figure(figsize=(25,25))
#sns.pairplot(df)
#plt.show()

# %%
sns.lmplot(x='station', y= 'Next_Tmax', data=df, palette='colorblind')

# %% [markdown]
# As we can see that station between 15-20 has record the maximum next day tempreture.

# %%
sns.lmplot(x='Present_Tmax', y= 'Next_Tmax', data=df, palette='colorblind')

# %% [markdown]
# As we can see that present day temperature and next day max  temperature are strongly related to each other.

# %%
sns.lmplot(x='Present_Tmin', y= 'Next_Tmax', data=df, palette='colorblind')

# %% [markdown]
# The present day minimum temperature and next day maximum temperature are strongly related to each other.

# %%
sns.lmplot(x='Present_Tmax', y= 'Present_Tmin', data=df, palette='colorblind')

# %% [markdown]
# As  we can see the present day min temperature and the present day max temperature is strongly correlated to each other, so we can drop one of the column to solve the problem of multicolinerity.

# %%
sns.lmplot(x='Present_Tmax', y= 'Next_Tmin', data=df, palette='colorblind')

# %%
sns.lmplot(x='Present_Tmin', y= 'Next_Tmin', data=df, palette='colorblind')

# %%
# deleting the present day min temperature
df.drop('Present_Tmin', axis=1, inplace=True)

# %%
sns.lmplot(x='LDAPS_RHmin', y= 'Next_Tmax', data=df, palette='colorblind')

# %% [markdown]
# The lapse rate is strongly relatecto next day max temerature.

# %%
variables = df[['LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4']].groupby(df.Next_Tmax).sum()
variables.plot(kind='area', fontsize=10,figsize=(6,4))
plt.title("Comparision between lapse year and next day max tempreture")
plt.xlabel("Next_Tmax")
plt.ylabel("Lapse year")
plt.show()

# %% [markdown]
# We can observed that the Lapse year cc4 is at max temperature.

# %%
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Year                0
# Month               0
# Day                 0
# dtype: int64

# %% [markdown]
# # Checking for the outliers

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=30:
        plt.subplot(5,6,p)
        sns.boxplot(df[i], palette='Set2_r')
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# As we can see the outliers are present in most of the columns , lets remove these outliers using zscore method or IQR technique.

# %%
from scipy.stats import zscore
out_features = df[['Present_Tmax', 'LDAPS_RHmax','LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4','DEM', 'Slope','Solar radiation', 'Month']]
z= np.abs(zscore(out_features))
z
# Out:
#       Present_Tmax  LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  \
# 0         0.361326     0.383078          0.524889          0.216663  0.128382
# 1         0.721084     0.311586          0.080895          0.223848  0.646994
# 2         0.619608     0.614982          0.162936          0.451210  0.441604
# 3         0.754909     1.133054          0.031092          0.079874  0.666247
# 4         0.551957     0.248765          0.170325          0.011187  0.627154
# ...            ...          ...               ...               ...       ...
# 7747      2.187892     1.328126          1.112066          2.029679  0.436683
# 7748      2.187892     1.548184          0.887662          2.047744  0.255421
# 7749      2.221718     1.555342          0.570780          2.137962  0.088072
# 7750      3.304127     4.113443          4.087857          3.959146  1.939757
# 7751      2.649126     1.624409          3.044561          2.616632  6.792009
#
# ...

# %%
#threshold=3
np.where(z>3)
# Out:
# (array([  25,   25,   26, ..., 7751, 7751, 7751], dtype=int64),
#  array([4, 7, 7, ..., 7, 8, 9], dtype=int64))

# %%
#so now removing the data above zscore and creating a new df
df1= df[(z<3).all(axis=1)]
df1.shape
# Out:
# (6928, 26)

# %%
print("Data loss percentage- ",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  10.62951496388029

# %%
#now using IQR method

#1st quantile
Q1 = out_features.quantile(0.25)

#3rd quantile
Q3 = out_features.quantile(0.75)

#IQR
IQR = Q3 - Q1

df2= df[~((df <(Q1 - 1.5 * IQR))|(df> (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (2463, 26)

# %%
print("Data loss percentage- ",((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  68.22755417956657

# %% [markdown]
# As we see that the zscore method will give the less amount of loss percentage data so we used df1 as our new dataframe

# %%
df=df1

# %%
df.shape
# Out:
# (6928, 26)

# %% [markdown]
# Now checking how the data has been distributed in each column

# %%
plt.figure(figsize=(20,25), facecolor='blue')
p=1

for column in df:
    if p<= 30:
        ax=plt.subplot(6,5,p)
        sns.distplot(df[column], color='r')
        plt.xlabel(column, fontsize=25)
    p+=1
plt.show()

# %% [markdown]
# # Checking for skewness

# %%
df.skew()
# Out:
# station             0.001387
# Present_Tmax       -0.278031
# LDAPS_RHmin         0.303775
# LDAPS_RHmax        -0.685133
# LDAPS_Tmax_lapse   -0.111758
# LDAPS_Tmin_lapse   -0.413662
# LDAPS_WS            1.084267
# LDAPS_LH            0.562357
# LDAPS_CC1           0.594533
# LDAPS_CC2           0.503511
# LDAPS_CC3           0.700406
# LDAPS_CC4           0.710606
# LDAPS_PPT1          3.741199
# LDAPS_PPT2          4.856792
# LDAPS_PPT3          5.489187
# LDAPS_PPT4          5.916334
# lat                 0.103646
# lon                -0.277123
# DEM                 1.757836
# Slope               1.591272
# Solar radiation    -0.503346
# Next_Tmax          -0.269520
# Next_Tmin          -0.331281
# Year                0.005631
# Month              -0.685773
# Day                 0.249993
# dtype: float64

# %% [markdown]
# As we can see the skewness in the column LDAPS_WS, LDAPS_PPT1, PPT2, PPT3, PPT4, DEM AND SLOPE, now removing these skewness using log 10 method

# %%
df['LDAPS_WS']= np.log10(df['LDAPS_WS'])

df['LDAPS_PPT1']= np.cbrt(df['LDAPS_PPT1'])

df['LDAPS_PPT2']= np.cbrt(df['LDAPS_PPT2'])

df['LDAPS_PPT3']= np.cbrt(df['LDAPS_PPT3'])

df['LDAPS_PPT4']= np.cbrt(df['LDAPS_PPT4'])

df['DEM']= np.log10(df['DEM'])

df['Slope']= np.log10(df['Slope'])

# %%
df.skew()
# Out:
# station             0.001387
# Present_Tmax       -0.278031
# LDAPS_RHmin         0.303775
# LDAPS_RHmax        -0.685133
# LDAPS_Tmax_lapse   -0.111758
# LDAPS_Tmin_lapse   -0.413662
# LDAPS_WS            0.376332
# LDAPS_LH            0.562357
# LDAPS_CC1           0.594533
# LDAPS_CC2           0.503511
# LDAPS_CC3           0.700406
# LDAPS_CC4           0.710606
# LDAPS_PPT1          1.857475
# LDAPS_PPT2          2.250775
# LDAPS_PPT3          2.391889
# LDAPS_PPT4          2.706629
# lat                 0.103646
# lon                -0.277123
# DEM                 0.413843
# Slope               0.065667
# Solar radiation    -0.503346
# Next_Tmax          -0.269520
# Next_Tmin          -0.331281
# Year                0.005631
# Month              -0.685773
# Day                 0.249993
# dtype: float64

# %% [markdown]
# we remove the almost skewness

# %%
# saved these data for next day minimum temp.
min_df=df

# %%
min_df.shape
# Out:
# (6928, 26)

# %% [markdown]
# # Correlation between target variable and independent variable

# %%
#checking correlation between features
df.corr()
# Out:
#                    station  Present_Tmax  LDAPS_RHmin  LDAPS_RHmax  \
# station           1.000000      0.110743    -0.067511    -0.170747
# Present_Tmax      0.110743      1.000000    -0.143286    -0.288067
# LDAPS_RHmin      -0.067511     -0.143286     1.000000     0.553336
# LDAPS_RHmax      -0.170747     -0.288067     0.553336     1.000000
# LDAPS_Tmax_lapse  0.067651      0.537558    -0.545883    -0.380727
# LDAPS_Tmin_lapse  0.104092      0.613293     0.140849    -0.130739
# LDAPS_WS          0.024133     -0.085602     0.201272     0.065646
# LDAPS_LH         -0.134565      0.124902    -0.040543     0.269392
# LDAPS_CC1         0.009367     -0.280138     0.577174     0.412074
# LDAPS_CC2         0.006756     -0.148976     0.715370     0.363561
# LDAPS_CC3         0.007031     -0.056427     0.657391     0.172451
# LDAPS_CC4         0.010311     -0.048394     0.459411     0.054422
# LDAPS_PPT1       -0.001474     -0.167936     0.405872     0.395275
# ...

# %% [markdown]
# This gives the correlation between independent variable and target variable. Lets visualize this by plotting heatmap

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True, fmt='0.2f', linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=15)
plt.title('Descriptive graph', fontsize=25)
plt.show()

# %% [markdown]
# We can observed that:
# 1) The next_tmax is strongly related to the maximum and minimum lapse year temperature.
# 2) Its negatively coorelated to the lapse year cc1, cc2, cc3 and cc4.
# 3) Dem and slope columns are strongly correlated to each other.
# 4) lapse year cc1, cc2, cc3 and cc4 are strongly related to each other.
# 5) Lapse year minimum and maximum temperature are also strongly correlated to each other.

# %%
#visualizing the correlation between target and label using bar plot
plt.figure(figsize=(22,8))
df.corr()['Next_Tmax'].sort_values(ascending=False).drop(['Next_Tmax']).plot(kind="bar",color="g")
plt.xlabel("Feature", fontsize = 17)
plt.ylabel("Target", fontsize= 17)
plt.title("correlation between label and feature", fontsize = 23)
plt.show()

# %% [markdown]
# As we can see that longitude and Month column are least related to the target variable so we drop these columns.

# %%
#dropping longitude and Month
df.drop(columns=['lon', 'Month'], axis=1, inplace=True)

# %% [markdown]
# # Seprating Feature and Label variable

# %%
x=df1.drop("Next_Tmax", axis=1)
y=df1["Next_Tmax"]

# %% [markdown]
# # Feature scaling using standard scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x= pd.DataFrame(scaler.fit_transform(x), columns= x.columns)
x
# Out:
#        station  Present_Tmax  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0    -1.672404     -0.425524     0.195800     0.438974         -0.653248
# 1    -1.533389      0.691146    -0.236965     0.364977         -0.005689
# 2    -1.394375      0.586458    -0.495002    -0.594053          0.082010
# 3    -1.255361      0.726042     0.194652     1.215225         -0.058927
# 4    -1.116347      0.516666     0.045467     0.299955         -0.274233
# ...        ...           ...          ...          ...               ...
# 6923  1.107879     -2.379697    -2.228396    -1.420183         -0.748529
# 6924  1.246894     -2.589073    -1.837983    -0.635064         -1.152315
# 6925  1.385908     -2.309905    -2.080177    -1.332182         -1.280917
# 6926  1.524922     -2.309905    -2.275221    -1.559950         -1.041038
# 6927  1.663936     -2.344801    -2.355214    -1.567359         -0.702304
#
#       LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  LDAPS_CC2  ...  \
# ...

# %% [markdown]
# We have scaled the data using standard scalarization to overcome the issue of biasness

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#     VIF values          Features
# 0     1.262347           station
# 1     2.601318      Present_Tmax
# 2     5.969941       LDAPS_RHmin
# 3     2.281085       LDAPS_RHmax
# 4     6.941180  LDAPS_Tmax_lapse
# 5     8.227852  LDAPS_Tmin_lapse
# 6     1.215745          LDAPS_WS
# 7     1.560121          LDAPS_LH
# 8     4.776350         LDAPS_CC1
# 9     5.391995         LDAPS_CC2
# 10    5.185092         LDAPS_CC3
# 11    3.014350         LDAPS_CC4
# 12    2.665123        LDAPS_PPT1
# 13    2.213075        LDAPS_PPT2
# 14    1.742844        LDAPS_PPT3
# 15    1.743130        LDAPS_PPT4
# 16    1.160202               lat
# 17    3.185087               DEM
# 18    2.838294             Slope
# 19    1.413233   Solar radiation
# 20    4.958536         Next_Tmin
# 21    1.121004              Year
# 22    1.268086               Day

# %% [markdown]
# As we can see that all the values are more than 10, so there is no problem of multicollinerity

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# Finding the best random State

# %%
# creating train test split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=10, random_state=i)
    lr= LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is", maxAccu,"On Random State", maxRs)
# Out:
# Maximum r2 score is 0.9474850426190273 On Random State 8

# %% [markdown]
# The best R2 score is 94.74% at random state 8

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.40, random_state = maxRs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR= LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_LR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.7710532682153153
# R2_score on training data: 77.73981577099038
# Mean Absolute Error: 1.0667169555012348
# Mean Squared Error: 1.943156091605167
# Root Mean Squared Error: 1.3939713381576992

# %% [markdown]
# The R2 score for this model is 77.10%

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_RFR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.8884359266545061
# R2_score on training data: 98.38901754920563
# Mean Absolute Error: 1.0667169555012348
# Mean Squared Error: 0.9468857975638677
# Root Mean Squared Error: 0.9730805709517931

# %% [markdown]
# The R2 score for this model is 88.88%

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print("R2_score:" , r2_score(y_test,pred_knn))
print("R2_score on training data: ", r2_score(y_train,pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:", mean_squared_error(y_test, pred_knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# R2_score: 0.8764745058302048
# R2_score on training data:  92.04351584539579
# Mean Aboslute Error: 0.7693704824481524
# Mean Squared Error: 1.0484068263106465
# Root Mean Squared Error: 1.0239173923274507

# %% [markdown]
# The R2 score for this model is 87.64%

# %%
gbr= GradientBoostingRegressor()
gbr.fit(x_train, y_train)
pred_gbr = gbr.predict(x_test)
pred_train = gbr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_gbr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_gbr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_gbr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_gbr)))
# Out:
# R2_score: 0.8490640940706787
# R2_score on training Data: 88.01607895145452
# Mean Aboslute Error: 0.8717795073564941
# Mean Squared Error: 1.2810491888756668
# Root Mean Squared Error: 1.1318344352756133

# %% [markdown]
# The R2 score for this model is 84.90%.

# %%
lasso= Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print("R2_score:", r2_score(y_test, pred_lasso))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:", mean_squared_error(y_test, pred_lasso))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_score: 0.5396369133154091
# R2_score on training Data: 54.01138247752755
# Mean Aboslute Error: 1.5717289627036957
# Mean Squared Error: 3.9072727934051317
# Root Mean Squared Error: 1.9766822692089723

# %% [markdown]
# The R2 score for this model is 53.96%

# %%
rd= Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print("R2_score:", r2_score(y_test, pred_rd))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:", mean_squared_error(y_test, pred_rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_rd)))
# Out:
# R2_score: 0.7710711938498984
# R2_score on training Data: 77.7397911150272
# Mean Aboslute Error: 1.0666610675532515
# Mean Squared Error: 1.9430039500752816
# Root Mean Squared Error: 1.393916765834776

# %% [markdown]
# The R2 score for this model is 77.10%

# %%
tr= ExtraTreesRegressor()
tr.fit(x_train, y_train)
pred_tr = tr.predict(x_test)
pred_train = tr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_tr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_tr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_tr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_tr)))
# Out:
# R2_score: 0.9154900581840503
# R2_score on training Data: 100.0
# Mean Aboslute Error: 0.6333312251035553
# Mean Squared Error: 0.717267317863701
# Root Mean Squared Error: 0.8469163582454297

# %% [markdown]
# The R2 score for this model is 91.62%

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()
xgb.fit(x_train,y_train)
pred_xgb = xgb.predict(x_test)
pred_train = xgb.predict(x_train)
print("R2_score:", r2_score(y_test, pred_xgb))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_xgb))
print("Mean Squared Error:", mean_squared_error(y_test, pred_xgb))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_xgb)))
# Out:
# R2_score: 0.9120799482352462
# R2_score on training Data: 99.51702086820178
# Mean Aboslute Error: 0.6479121012676482
# Mean Squared Error: 0.7462101897204344
# Root Mean Squared Error: 0.8638345846980395

# %% [markdown]
# The R2 score for this model is 91.20%

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada.fit(x_train, y_train)
pred_ada = ada.predict(x_test)
pred_train = ada.predict(x_train)
print("R2_score:", r2_score(y_test, pred_ada))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_ada))
print("Mean Squared Error:", mean_squared_error(y_test, pred_ada))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_ada)))
# Out:
# R2_score: 0.7507027142053171
# R2_score on training Data: 77.90021909527636
# Mean Aboslute Error: 1.173625689451838
# Mean Squared Error: 2.11587881485093
# Root Mean Squared Error: 1.4546060686147746

# %% [markdown]
# The R2 score for this model is 75.48%

# %% [markdown]
# # Cross validation of the models

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between cross validation score and R2 score at LinearRegression is:",(r2_score(y_test,pred_LR)- score.mean())*100)
# Out:
# [0.7301322  0.66607861 0.6789074  0.75079673 0.60104035]
# 0.6853910571461952
# Difference between cross validation score and R2 score at LinearRegression is: 8.566221106912009

# %%
score1= cross_val_score(RFR,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between cross validation score and R2 score at RandomForestRegressor is:",(r2_score(y_test,pred_RFR)- score.mean())*100)
# Out:
# [0.68619753 0.65450025 0.66621561 0.7413466  0.62487905]
# 0.6746278078754531
# Difference between cross validation score and R2 score at RandomForestRegressor is: 20.30448695083109

# %%
score3= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between cross validation score and R2 score at knn is:",(r2_score(y_test,pred_knn)- score.mean())*100)
# Out:
# [0.57487196 0.38574717 0.53633354 0.65939727 0.54441238]
# 0.5401524649366831
# Difference between cross validation score and R2 score at knn is: 19.108344868400962

# %%
score4= cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print("Difference between cross validation score and R2 score at GradientBoostingRegressor is:",(r2_score(y_test,pred_gbr)- score.mean())*100)
# Out:
# [0.73026021 0.6724569  0.67569623 0.78250965 0.64748213]
# 0.7016810248756359
# Difference between cross validation score and R2 score at GradientBoostingRegressor is: 16.367303692448353

# %%
score5= cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print("Difference between cross validation score and R2 score at lasso is:",(r2_score(y_test,pred_lasso)- score.mean())*100)
# Out:
# [0.46766128 0.4679406  0.55743117 0.3845435  0.52592094]
# 0.4806994975066101
# Difference between cross validation score and R2 score at lasso is: -14.575414383078611

# %%
score6= cross_val_score(rd,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print("Difference between cross validation score and R2 score at Ridge is:",(r2_score(y_test,pred_rd)- score.mean())*100)
# Out:
# [0.73024332 0.66608079 0.67886485 0.75085521 0.60111414]
# 0.6854316610937256
# Difference between cross validation score and R2 score at Ridge is: 8.568013670370323

# %%
score8= cross_val_score(tr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print("Difference between cross validation score and R2 score at ExtraTreesRegressor is:",(r2_score(y_test,pred_tr)- score.mean())*100)
# Out:
# [0.71399738 0.64271148 0.69723703 0.76588585 0.59741244]
# 0.6834488371584637
# Difference between cross validation score and R2 score at ExtraTreesRegressor is: 23.009900103785508

# %%
score9= cross_val_score(xgb,x,y,cv=5,scoring='r2')
print(score9)
print(score9.mean())
print("Difference between cross validation score and R2 score at xgbregressor is:",(r2_score(y_test,pred_xgb)- score.mean())*100)
# Out:
# [0.69707236 0.61680973 0.65736351 0.70216674 0.62387811]
# 0.6594580910972153
# Difference between cross validation score and R2 score at xgbregressor is: 22.6688891089051

# %%
score10= cross_val_score(ada,x,y,cv=5,scoring='r2')
print(score10)
print(score10.mean())
print("Difference between cross validation score and R2 score at AdaBoostRegressor is:",(r2_score(y_test,pred_ada)- score.mean())*100)
# Out:
# [0.65404985 0.63143629 0.62647058 0.71720853 0.61020962]
# 0.6478749723657344
# Difference between cross validation score and R2 score at AdaBoostRegressor is: 6.53116570591219

# %% [markdown]
# # conclusion

# %% [markdown]
# From the differnece between R2 score and cross validation score we can conclude that ADA boost Regressor is our best fitted model.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters= {'n_estimators':[10, 25, 50, 100],
            'learning_rate':[1.0, 5.0, 2.5, 5.5],
            'loss':['linear', 'square', 'exponential'],
            'random_state':[5,10,50,100]}

# %%
GCV=GridSearchCV(AdaBoostRegressor(),parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [1.0, 5.0, 2.5, 5.5],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [10, 25, 50, 100],
#                          'random_state': [5, 10, 50, 100]})

# %%
GCV.best_params_
# Out:
# {'learning_rate': 5.5,
#  'loss': 'exponential',
#  'n_estimators': 100,
#  'random_state': 50}

# %%
Final_model = AdaBoostRegressor(learning_rate= 5.5, loss='exponential', n_estimators=100, random_state=50)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print('R2_score:', r2_score(y_test, pred))
print("Mean_absolute_error:", mean_absolute_error(y_test,pred))
print("Mean Squared Error:", mean_squared_error(y_test,pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.7896746878905954
# Mean_absolute_error: 1.0764014161318989
# Mean Squared Error: 1.785109174777428
# Root Mean Squared Error: 1.336079778597606

# %% [markdown]
# So the best R2 score for the final model is 78.96%

# %% [markdown]
# # Saving the model

# %%
#saving the model using.pkl
import joblib
joblib.dump(Final_model, "Temperature Forecast.pkl")
# Out:
# ['Temperature Forecast.pkl']

# %%
import pickle
filename='Temperature Forecast.pkl'
pickle.dump(Final_model,open(filename,'wb'))

# %%
import pickle
loaded_model= pickle.load(open('Temperature Forecast.pkl', 'rb'))
result= loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 78.96746878905954

# %%
conclusion= pd.DataFrame([loaded_model.predict(x_test)[:], y_test[:]], index=["Predicted", "Original"])
conclusion
# Out:
#                 0          1          2          3          4          5     \
# Predicted  28.603299  32.377212  29.313352  29.986224  32.053348  34.761667
# Original   28.500000  34.000000  30.200000  29.400000  31.500000  35.500000
#
#                 6          7          8          9     ...       2762  \
# Predicted  34.304469  26.154437  32.222781  26.132862  ...  31.147387
# Original   35.000000  25.800000  31.300000  23.800000  ...  32.100000
#
#                2763       2764    2765       2766       2767       2768  \
# Predicted  31.93004  31.516678  28.935  34.338023  27.604272  26.972058
# Original   32.00000  29.100000  27.900  33.800000  25.700000  26.700000
#
#                 2769       2770       2771
# Predicted  32.230074  34.632452  28.890946
# Original   31.300000  35.400000  27.800000
#
# [2 rows x 2772 columns]

# %% [markdown]
# # Predicting model for next Day minimum Temperature

# %% [markdown]
# We already saved our dataset for next day minimum tempretature after removing the skewness.

# %%
df=min_df

# %%
df.shape
# Out:
# (6928, 24)

# %% [markdown]
# # Correlation between target variable and independent variable

# %%
#checking correlation between features
df.corr()
# Out:
#                    station  Present_Tmax  LDAPS_RHmin  LDAPS_RHmax  \
# station           1.000000      0.110743    -0.067511    -0.170747
# Present_Tmax      0.110743      1.000000    -0.143286    -0.288067
# LDAPS_RHmin      -0.067511     -0.143286     1.000000     0.553336
# LDAPS_RHmax      -0.170747     -0.288067     0.553336     1.000000
# LDAPS_Tmax_lapse  0.067651      0.537558    -0.545883    -0.380727
# LDAPS_Tmin_lapse  0.104092      0.613293     0.140849    -0.130739
# LDAPS_WS          0.024133     -0.085602     0.201272     0.065646
# LDAPS_LH         -0.134565      0.124902    -0.040543     0.269392
# LDAPS_CC1         0.009367     -0.280138     0.577174     0.412074
# LDAPS_CC2         0.006756     -0.148976     0.715370     0.363561
# LDAPS_CC3         0.007031     -0.056427     0.657391     0.172451
# LDAPS_CC4         0.010311     -0.048394     0.459411     0.054422
# LDAPS_PPT1       -0.001474     -0.167936     0.405872     0.395275
# ...

# %% [markdown]
# This gives the correlation between independent variable and target variable. Lets visualize this by plotting heatmap

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True, fmt='0.2f', linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=15)
plt.title('Descriptive graph', fontsize=25)
plt.show()

# %%
#visualizing the correlation between target and label using bar plot
plt.figure(figsize=(22,8))
df.corr()['Next_Tmin'].sort_values(ascending=False).drop(['Next_Tmin']).plot(kind="bar",color="g")
plt.xlabel("Feature", fontsize = 17)
plt.ylabel("Target", fontsize= 17)
plt.title("correlation between label and feature", fontsize = 23)
plt.show()

# %% [markdown]
# As we can see that the column LDAPS_WS, LDAPS_CC3, LDAPS_PPT3 has very less corelation with the target variable, so we can drop these columns

# %%
df.drop(columns=['LDAPS_WS', 'LDAPS_CC3', 'LDAPS_PPT3'], axis=1, inplace=True)

# %% [markdown]
# # Seprating Feature and Label variable

# %%
x=df.drop("Next_Tmin", axis=1)
y=df1["Next_Tmin"]

# %% [markdown]
# # Feature scaling using standard scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x= pd.DataFrame(scaler.fit_transform(x), columns= x.columns)
x
# Out:
#        station  Present_Tmax  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0    -1.672404     -0.425524     0.195800     0.438974         -0.653248
# 1    -1.533389      0.691146    -0.236965     0.364977         -0.005689
# 2    -1.394375      0.586458    -0.495002    -0.594053          0.082010
# 3    -1.255361      0.726042     0.194652     1.215225         -0.058927
# 4    -1.116347      0.516666     0.045467     0.299955         -0.274233
# ...        ...           ...          ...          ...               ...
# 6923  1.107879     -2.379697    -2.228396    -1.420183         -0.748529
# 6924  1.246894     -2.589073    -1.837983    -0.635064         -1.152315
# 6925  1.385908     -2.309905    -2.080177    -1.332182         -1.280917
# 6926  1.524922     -2.309905    -2.275221    -1.559950         -1.041038
# 6927  1.663936     -2.344801    -2.355214    -1.567359         -0.702304
#
#       LDAPS_Tmin_lapse  LDAPS_LH  LDAPS_CC1  LDAPS_CC2  LDAPS_CC4  LDAPS_PPT1  \
# ...

# %% [markdown]
# We have scaled the data using standard scalarization to overcome the issue of biasness

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#     VIF values          Features
# 0     1.267109           station
# 1     2.521020      Present_Tmax
# 2     5.533058       LDAPS_RHmin
# 3     2.204756       LDAPS_RHmax
# 4     7.945417  LDAPS_Tmax_lapse
# 5     6.104669  LDAPS_Tmin_lapse
# 6     1.545380          LDAPS_LH
# 7     4.776945         LDAPS_CC1
# 8     5.033287         LDAPS_CC2
# 9     2.104180         LDAPS_CC4
# 10    2.635863        LDAPS_PPT1
# 11    2.145513        LDAPS_PPT2
# 12    1.475076        LDAPS_PPT4
# 13    1.156956               lat
# 14    3.018152               DEM
# 15    2.809796             Slope
# 16    1.378816   Solar radiation
# 17    3.813044         Next_Tmax
# 18    1.085165              Year
# 19    1.249383               Day

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# ~Finding the best random State

# %%
# creating train test split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=10, random_state=i)
    lr= LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is", maxAccu,"On Random State", maxRs)
# Out:
# Maximum r2 score is 0.9698931904316289 On Random State 69

# %% [markdown]
# The best R2 score is 96.98 at random state 69

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.40, random_state = maxRs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR= LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_LR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.803431335887667
# R2_score on training data: 82.19386407984962
# Mean Absolute Error: 0.8270167492985537
# Mean Squared Error: 1.1001316450697707
# Root Mean Squared Error: 1.0488716056170893

# %% [markdown]
# The R2 score for this model is 80.34%

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_RFR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.8860464753450614
# R2_score on training data: 98.48164409262436
# Mean Absolute Error: 0.8270167492985537
# Mean Squared Error: 0.6377612581652111
# Root Mean Squared Error: 0.7985995605841586

# %% [markdown]
# The R2 score for this model is 88.60%

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print("R2_score:" , r2_score(y_test,pred_knn))
print("R2_score on training data: ", r2_score(y_train,pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:", mean_squared_error(y_test, pred_knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# R2_score: 0.852219818594831
# R2_score on training data:  90.91802091996144
# Mean Aboslute Error: 0.6976449450585374
# Mean Squared Error: 0.8270781856922502
# Root Mean Squared Error: 0.9094383902674498

# %% [markdown]
# The R2 score for this model is 85.22%

# %%
gbr= GradientBoostingRegressor()
gbr.fit(x_train, y_train)
pred_gbr = gbr.predict(x_test)
pred_train = gbr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_gbr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_gbr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_gbr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_gbr)))
# Out:
# R2_score: 0.8751308921763836
# R2_score on training Data: 90.85078301189529
# Mean Aboslute Error: 0.6522798050256902
# Mean Squared Error: 0.698852269402846
# Root Mean Squared Error: 0.8359738449274869

# %% [markdown]
# The R2 score for this model is 87.51%

# %%
lasso= Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print("R2_score:", r2_score(y_test, pred_lasso))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:", mean_squared_error(y_test, pred_lasso))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_score: 0.587108757866536
# R2_score on training Data: 59.87149474565852
# Mean Aboslute Error: 1.2083670187073323
# Mean Squared Error: 2.3108195983038646
# Root Mean Squared Error: 1.5201380194916068

# %% [markdown]
# The R2 score for this model is 58.71%

# %%
rd= Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print("R2_score:", r2_score(y_test, pred_rd))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:", mean_squared_error(y_test, pred_rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_rd)))
# Out:
# R2_score: 0.8034299263497924
# R2_score on training Data: 82.19385057841436
# Mean Aboslute Error: 0.827019856685841
# Mean Squared Error: 1.1001395338002955
# Root Mean Squared Error: 1.0488753661900423

# %% [markdown]
# The R2 score for this model is 80.34%

# %%
tr= ExtraTreesRegressor()
tr.fit(x_train, y_train)
pred_tr = tr.predict(x_test)
pred_train = tr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_tr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_tr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_tr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_tr)))
# Out:
# R2_score: 0.8945374612248183
# R2_score on training Data: 100.0
# Mean Aboslute Error: 0.5915493327169057
# Mean Squared Error: 0.5902399388015975
# Root Mean Squared Error: 0.76827074576714

# %% [markdown]
# The R2 score for this model is 89.45%

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()
xgb.fit(x_train,y_train)
pred_xgb = xgb.predict(x_test)
pred_train = xgb.predict(x_train)
print("R2_score:", r2_score(y_test, pred_xgb))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_xgb))
print("Mean Squared Error:", mean_squared_error(y_test, pred_xgb))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_xgb)))
# Out:
# R2_score: 0.9159649946305888
# R2_score on training Data: 99.54396933030641
# Mean Aboslute Error: 0.5242754949568553
# Mean Squared Error: 0.4703169201356799
# Root Mean Squared Error: 0.6857965588537754

# %% [markdown]
# The R2 score for this model is 91.59%

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada.fit(x_train, y_train)
pred_ada = ada.predict(x_test)
pred_train = ada.predict(x_train)
print("R2_score:", r2_score(y_test, pred_ada))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_ada))
print("Mean Squared Error:", mean_squared_error(y_test, pred_ada))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_ada)))
# Out:
# R2_score: 0.7833154656621533
# R2_score on training Data: 80.95335753374846
# Mean Aboslute Error: 0.8983908403727328
# Mean Squared Error: 1.2127137064229363
# Root Mean Squared Error: 1.1012328120896764

# %% [markdown]
# The R2 score for this model is 78.33%

# %% [markdown]
# # Cross validation of the models

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between cross validation score and R2 score at LinearRegression is:",(r2_score(y_test,pred_LR)- score.mean())*100)
# Out:
# [0.69747748 0.65838521 0.79150421 0.81528676 0.84499836]
# 0.7615304043441793
# Difference between cross validation score and R2 score at LinearRegression is: 4.190093154348773

# %%
score1= cross_val_score(RFR,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between cross validation score and R2 score at RandomForestRegressor is:",(r2_score(y_test,pred_RFR)- score.mean())*100)
# Out:
# [0.71221993 0.68885202 0.82069223 0.84642564 0.86184102]
# 0.7860061679440294
# Difference between cross validation score and R2 score at RandomForestRegressor is: 12.451607100088214

# %%
score3= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between cross validation score and R2 score at knn is:",(r2_score(y_test,pred_knn)- score.mean())*100)
# Out:
# [0.34809    0.40365389 0.6093191  0.69869496 0.76307688]
# 0.5645669663540689
# Difference between cross validation score and R2 score at knn is: 9.06894142506517

# %%
score4= cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print("Difference between cross validation score and R2 score at GradientBoostingRegressor is:",(r2_score(y_test,pred_gbr)- score.mean())*100)
# Out:
# [0.72855385 0.68891516 0.82819964 0.84767698 0.87146378]
# 0.7929618814108158
# Difference between cross validation score and R2 score at GradientBoostingRegressor is: 11.360048783220433

# %%
score5= cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print("Difference between cross validation score and R2 score at lasso is:",(r2_score(y_test,pred_lasso)- score.mean())*100)
# Out:
# [0.54232101 0.40541376 0.55717491 0.47900307 0.61957128]
# 0.5206968055258834
# Difference between cross validation score and R2 score at lasso is: -17.442164647764326

# %%
score6= cross_val_score(rd,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print("Difference between cross validation score and R2 score at Ridge is:",(r2_score(y_test,pred_rd)- score.mean())*100)
# Out:
# [0.69745645 0.65844739 0.79148213 0.81530463 0.84501342]
# 0.7615408041095182
# Difference between cross validation score and R2 score at Ridge is: 4.189952200561309

# %%
score8= cross_val_score(tr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print("Difference between cross validation score and R2 score at ExtraTreesRegressor is:",(r2_score(y_test,pred_tr)- score.mean())*100)
# Out:
# [0.70717997 0.69074886 0.81760364 0.8480005  0.87398494]
# 0.7875035812395692
# Difference between cross validation score and R2 score at ExtraTreesRegressor is: 13.300705688063896

# %%
score9= cross_val_score(xgb,x,y,cv=5,scoring='r2')
print(score9)
print(score9.mean())
print("Difference between cross validation score and R2 score at xgbregressor is:",(r2_score(y_test,pred_xgb)- score.mean())*100)
# Out:
# [0.68056061 0.67870574 0.80511268 0.83776407 0.85853778]
# 0.7721361739683861
# Difference between cross validation score and R2 score at xgbregressor is: 15.443459028640948

# %%
score10= cross_val_score(ada,x,y,cv=5,scoring='r2')
print(score10)
print(score10.mean())
print("Difference between cross validation score and R2 score at AdaBoostRegressor is:",(r2_score(y_test,pred_ada)- score.mean())*100)
# Out:
# [0.63680535 0.61529898 0.77168869 0.77262109 0.80963773]
# 0.7212103678072428
# Difference between cross validation score and R2 score at AdaBoostRegressor is: 2.1785061317973975

# %% [markdown]
# # conclusion

# %% [markdown]
# From the differnece between R2 score and cross validation score we can conclude that ADA boost Regressor is our best fitted model.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters= {'n_estimators':[10, 25, 50, 100],
            'learning_rate':[1.0, 5.0, 2.5, 5.5],
            'loss':['linear', 'square', 'exponential'],
            'random_state':[5,10,50,100]}

# %%
GCV=GridSearchCV(AdaBoostRegressor(),parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [1.0, 5.0, 2.5, 5.5],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [10, 25, 50, 100],
#                          'random_state': [5, 10, 50, 100]})

# %%
 GCV.best_params_
# Out:
# {'learning_rate': 5.5,
#  'loss': 'exponential',
#  'n_estimators': 100,
#  'random_state': 100}

# %%
Final_model = AdaBoostRegressor(learning_rate= 5.5, loss='exponential', n_estimators=100, random_state=100)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print('R2_score:', r2_score(y_test, pred))
print("Mean_absolute_error:", mean_absolute_error(y_test,pred))
print("Mean Squared Error:", mean_squared_error(y_test,pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.807307919119612
# Mean_absolute_error: 0.8446753736606009
# Mean Squared Error: 1.078435654472956
# Root Mean Squared Error: 1.03847756570518

# %% [markdown]
# So the best R2 score for the final model 80.73%

# %% [markdown]
# # Saving the model

# %%
#saving the model using.pkl
import joblib
joblib.dump(Final_model, "Temperature Forecast_min.pkl")
# Out:
# ['Temperature Forecast_min.pkl']

# %%
import pickle
filename='Temperature Forecast_min.pkl'
pickle.dump(Final_model,open(filename,'wb'))

# %%
import pickle
loaded_model= pickle.load(open('Temperature Forecast_min.pkl', 'rb'))
result= loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 80.73079191196119

# %%
conclusion= pd.DataFrame([loaded_model.predict(x_test)[:], y_test[:]], index=["Predicted", "Original"])
conclusion
# Out:
#                 0          1          2          3          4          5     \
# Predicted  25.848576  26.347013  23.430627  24.694293  20.792964  19.097674
# Original   27.500000  25.900000  24.000000  24.800000  21.200000  18.200000
#
#                 6          7          8          9     ...       2762  \
# Predicted  22.370585  19.904729  22.601205  21.776648  ...  21.894454
# Original   23.600000  20.500000  22.800000  21.400000  ...  20.200000
#
#                 2763      2764       2765       2766       2767       2768  \
# Predicted  21.484349  18.46686  23.079317  23.301416  19.269692  22.482828
# Original   20.800000  18.60000  24.400000  24.700000  18.500000  23.000000
#
#              2769       2770       2771
# Predicted  20.663  22.715211  22.433333
# Original   22.300  24.000000  23.400000
#
# [2 rows x 2772 columns]

# %% [markdown]
# # Concluding Remarks

# %% [markdown]
# We did the model prediction for both i.e. for next day maximum temperature and next day minimum temperature.
#
# For both the target value AdaBoostRegressor is the best fitted model.
#
# We got 78.96% accuracy score for next day maximum Temperature.
#
# We got 80.73% accuracy score for next day minimum temperature.
#
# AS there is not much of difference for both the target value.
#
# We got this accuracy score by removing null values, removing outliers, removing skewness, checking multicollinerity, and did the Variance inflation factor.
#
# By dooing all these steps we got accuracy score.
