# %% [markdown]
# # Zomato Restaurant

# %% [markdown]
# # Project Description

# %% [markdown]
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.

# %% [markdown]
# # Problem Statement:

# %% [markdown]
#  In this dataset we have to  predict 2 things –
# 1) Average Cost for two
# 2) Price range

# %% [markdown]
# # Importing Necessary Libararies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing datasets

# %%
df1= pd.read_csv('Country-Code (1).csv')

# %%
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df1.shape
# Out:
# (15, 2)

# %%
df2= pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv', encoding=('ISO-8859-1'))

# %%
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2.shape
# Out:
# (9551, 21)

# %% [markdown]
# # Merging all the database in one database.

# %%
df=pd.concat([df1,df2])

# %%
df
# Out:
#       Country Code    Country  Restaurant ID           Restaurant Name  \
# 0                1      India            NaN                       NaN
# 1               14  Australia            NaN                       NaN
# 2               30     Brazil            NaN                       NaN
# 3               37     Canada            NaN                       NaN
# 4               94  Indonesia            NaN                       NaN
# ...            ...        ...            ...                       ...
# 9546           208        NaN      5915730.0              NamlÛ± Gurme
# 9547           208        NaN      5908749.0             Ceviz AÛôacÛ±
# 9548           208        NaN      5915807.0                     Huqqa
# 9549           208        NaN      5916112.0              Aôôk Kahve
# 9550           208        NaN      5927402.0  Walter's Coffee Roastery
#
#            City                                            Address  \
# ...

# %% [markdown]
# # First predicting a model for Average cost for two people.

# %%
df.shape
# Out:
# (9566, 22)

# %% [markdown]
# AS we can see that we have 9566 rows and 22 columns in this dataset.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (9566, 22)

# %% [markdown]
# In the above dataframe there are 9566 rows and 22 columns, out of which one is target variable and the remaining are independent variable.

# %%
df.columns
# Out:
# Index(['Country Code', 'Country', 'Restaurant ID', 'Restaurant Name', 'City',
#        'Address', 'Locality', 'Locality Verbose', 'Longitude', 'Latitude',
#        'Cuisines', 'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Country Code',
#  'Country',
#  'Restaurant ID',
#  'Restaurant Name',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
#lets check the data types of the features
df.dtypes
# Out:
# Country Code              int64
# Country                  object
# Restaurant ID           float64
# Restaurant Name          object
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two    float64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range             float64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                   float64
# dtype: object

# %% [markdown]
# As we can observed that there are 3 types of datatypes(float, integer and object) present in the dataset.

# %%
# Let us fund the Unique values present in our data
df.nunique()
# Out:
# Country Code              15
# Country                   15
# Restaurant ID           9551
# Restaurant Name         7446
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# dtype: int64

# %%
#Now Let us find the values of each Features in our data
for i in df.columns:
        print(df[i].value_counts())
        print('/n')
# Out:
# 1      8653
# 216     435
# 215      81
# 30       61
# 189      61
# 214      61
# 148      41
# 208      35
# 14       25
# 162      23
# 94       22
# 166      21
# 184      21
# 191      21
# 37        5
# Name: Country Code, dtype: int64
# /n
# India             1
# Australia         1
# Brazil            1
# Canada            1
# Indonesia         1
# New Zealand       1
# Phillipines       1
# Qatar             1
# Singapore         1
# South Africa      1
# Sri Lanka         1
# Turkey            1
# UAE               1
# United Kingdom    1
# United States     1
# Name: Country, dtype: int64
# /n
# 6317637.0     1
# 18254520.0    1
# 18462589.0    1
# 18336474.0    1
# 18336477.0    1
#              ..
# 313059.0      1
# 763.0         1
# 7557.0        1
# 525.0         1
# 5927402.0     1
# Name: Restaurant ID, Length: 9551, dtype: int64
# /n
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# ...

# %% [markdown]
# # Checking the null values

# %%
df.isnull().sum()
# Out:
# Country Code               0
# Country                 9551
# Restaurant ID             15
# Restaurant Name           15
# City                      15
# Address                   15
# Locality                  15
# Locality Verbose          15
# Longitude                 15
# Latitude                  15
# Cuisines                  24
# Average Cost for two      15
# Currency                  15
# Has Table booking         15
# Has Online delivery       15
# Is delivering now         15
# Switch to order menu      15
# Price range               15
# Aggregate rating          15
# Rating color              15
# Rating text               15
# Votes                     15
# dtype: int64

# %% [markdown]
# Before that we seprate the categorical column an dnumerical column

# %% [markdown]
# # Seprating numerical columns and categorical column

# %%
#checking for categorical column
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i] == 'object':
        categorical_col.append(i)
print("Categorical columns:", categorical_col)
print('\n')

#checking for numerical column
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i] != 'object':
        numerical_col.append(i)
print("Numerical columns:", numerical_col)
print('\n')
# Out:
# Categorical columns: ['Country', 'Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text']
#
#
# Numerical columns: ['Country Code', 'Restaurant ID', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
#again check the null values.
df.isnull().sum()
# Out:
# Country Code               0
# Country                 9551
# Restaurant ID             15
# Restaurant Name           15
# City                      15
# Address                   15
# Locality                  15
# Locality Verbose          15
# Longitude                 15
# Latitude                  15
# Cuisines                  24
# Average Cost for two      15
# Currency                  15
# Has Table booking         15
# Has Online delivery       15
# Is delivering now         15
# Switch to order menu      15
# Price range               15
# Aggregate rating          15
# Rating color              15
# Rating text               15
# Votes                     15
# dtype: int64

# %% [markdown]
# As we can observed that the column country has 9556 columns are null out of 9566, so we delete this column.

# %%
#df.drop('Country', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# Country Code               0
# Country                 9551
# Restaurant ID             15
# Restaurant Name           15
# City                      15
# Address                   15
# Locality                  15
# Locality Verbose          15
# Longitude                 15
# Latitude                  15
# Cuisines                  24
# Average Cost for two      15
# Currency                  15
# Has Table booking         15
# Has Online delivery       15
# Is delivering now         15
# Switch to order menu      15
# Price range               15
# Aggregate rating          15
# Rating color              15
# Rating text               15
# Votes                     15
# dtype: int64

# %% [markdown]
# As we can see that almost all the columns have null values. lets visualize it using a heatmap also.

# %%
#lets visualize it using a heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# From the heatmap also we can observed that all the columns have null nalues,lets remove these null values using mode and mean method.

# %%
#removing null values from categorical column.

df['Restaurant Name'] = df['Restaurant Name'].fillna(df['Restaurant Name'].mode()[0])
df['City'] = df['City'].fillna(df['City'].mode()[0])
df['Address'] = df['Address'].fillna(df['Address'].mode()[0])
df['Locality'] = df['Locality'].fillna(df['Locality'].mode()[0])
df['Locality Verbose'] = df['Locality Verbose'].fillna(df['Locality Verbose'].mode()[0])
df['Cuisines'] = df['Cuisines'].fillna(df['Cuisines'].mode()[0])
df['Currency'] = df['Currency'].fillna(df['Currency'].mode()[0])
df['Has Table booking'] = df['Has Table booking'].fillna(df['Has Table booking'].mode()[0])
df['Has Online delivery'] = df['Has Online delivery'].fillna(df['Has Online delivery'].mode()[0])
df['Is delivering now'] = df['Is delivering now'].fillna(df['Is delivering now'].mode()[0])
df['Switch to order menu'] = df['Switch to order menu'].fillna(df['Switch to order menu'].mode()[0])
df['Rating color'] = df['Rating color'].fillna(df['Rating color'].mode()[0])
df['Rating text'] = df['Rating text'].fillna(df['Rating text'].mode()[0])
df['Country'] = df['Country'].fillna(df['Country'].mode()[0])

# %%
# removing null values from numerical value
df["Restaurant ID"] = df["Restaurant ID"].fillna(df["Restaurant ID"].mean())
df["Longitude"] = df["Longitude"].fillna(df["Longitude"].mean())
df["Latitude"] = df["Latitude"].fillna(df["Latitude"].mean())
df["Average Cost for two"] = df["Average Cost for two"].fillna(df["Average Cost for two"].mean())
df["Price range"] = df["Price range"].fillna(df["Price range"].mean())
df["Aggregate rating"] = df["Aggregate rating"].fillna(df["Aggregate rating"].mean())
df["Votes"] = df["Votes"].fillna(df["Votes"].mean())

# %%
#again checking the null values
df.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#lets visualize it using a heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# We can removed all the null values from the dataset.

# %% [markdown]
# ~Checking duplicates values in the column

# %%
print("Total duplicates values are:", df.duplicated().sum())
# Out:
# Total duplicates values are: 0

# %% [markdown]
# There are no duplicate values in the dataset

# %%
#Checking for the whitespaces in the columns
df.loc[df['Average Cost for two']==" "]
# Out:
# Empty DataFrame
# Columns: [Country Code, Country, Restaurant ID, Restaurant Name, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# There are no whitespaces in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9566 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9566 non-null   int64
#  1   Country               9566 non-null   object
#  2   Restaurant ID         9566 non-null   float64
#  3   Restaurant Name       9566 non-null   object
#  4   City                  9566 non-null   object
#  5   Address               9566 non-null   object
#  6   Locality              9566 non-null   object
#  7   Locality Verbose      9566 non-null   object
#  8   Longitude             9566 non-null   float64
#  9   Latitude              9566 non-null   float64
#  10  Cuisines              9566 non-null   object
#  11  Average Cost for two  9566 non-null   float64
#  12  Currency              9566 non-null   object
#  13  Has Table booking     9566 non-null   object
#  14  Has Online delivery   9566 non-null   object
# ...

# %%
# Let us fund the Unique values present in our data
df.nunique()
# Out:
# Country Code              15
# Country                   15
# Restaurant ID           9552
# Restaurant Name         7446
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8121
# Latitude                8678
# Cuisines                1825
# Average Cost for two     141
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                5
# Aggregate rating          34
# Rating color               6
# Rating text                6
# Votes                   1013
# dtype: int64

# %% [markdown]
# # Description of dataset

# %%
#statistical summary of the numerical columns
df.describe()
# Out:
#        Country Code  Restaurant ID    Longitude     Latitude  \
# count   9566.000000   9.566000e+03  9566.000000  9566.000000
# mean      18.553105   9.051128e+06    64.126574    25.854381
# std       56.985333   8.784625e+06    41.434530    10.999300
# min        1.000000   5.300000e+01  -157.948486   -41.330428
# 25%        1.000000   3.020025e+05    77.081065    28.478035
# 50%        1.000000   6.103233e+06    77.191820    28.570360
# 75%        1.000000   1.835228e+07    77.281702    28.642718
# max      216.000000   1.850065e+07   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9566.000000  9566.000000       9566.000000   9566.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16108.537353     0.904898          1.515188    429.831714
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# This gives the statstical summary of the numerical column. The summary of the dataset looks perfect as there are no negative values or invalid values present in the dataset.From the above dataset we can observed the following:
#
# 1) As the value counts of each column is same, it means no values are missing in the dataset.
# 2) The mean value in the column country code, Restaurant id, Average cost for two, and votes are more than the median value, it means data is skewed to the right side.
# 3) The mean value in the column longitude, latitude, aggregate rating is less than the median value, it means data is skewed to the left side.
# 4) There is a difference between 75% and the max value, it means outliers are present.
# 5) We can also observed the min and standard deviation.

# %% [markdown]
# # Data Visualization

# %%
# Distribution of Price Range
plt.hist(df['Price range'], color='skyblue', edgecolor='black')
plt.title('Distribution of Price Range')
plt.xlabel('Price Range')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see that the price range is higher between 1.0 to 1.5

# %%
# Distribution of Price Range
plt.hist(df['Average Cost for two'], color='skyblue', edgecolor='black')
plt.title('Distribution of Average cost')
plt.xlabel('Average cost')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# The average cost is between 0-25000.

# %%
# Distribution of Aggregate Rating
plt.hist(df['Aggregate rating'], color='skyblue', edgecolor='black')
plt.title('Distribution of Aggregate Rating')
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# Aggregate rating for the product is higher between 3-4

# %%
# Distribution of Votes
plt.hist(df['Votes'], color='skyblue', edgecolor='black')
plt.title('Distribution of Votes')
plt.xlabel('Votes')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# The voting for the food is higher at starting point only.

# %%
# Pairplot for numerical variables
sns.pairplot(df)
plt.show()

# %% [markdown]
# we can see the distribution of every columns with each other.

# %%
# Count of restaurants with table booking
sns.countplot(data=df, x='Has Table booking', palette='Set2')
plt.title('Has Table Booking')
# Out:
# Text(0.5, 1.0, 'Has Table Booking')

# %% [markdown]
# we can see that the maximum people were not booked the table.

# %%
# Count of restaurants with online delivery
sns.countplot(data=df, x='Has Online delivery', palette='Set2')
plt.title('Has Online Delivery')
# Out:
# Text(0.5, 1.0, 'Has Online Delivery')

# %% [markdown]
# Maximum people are not gone for the online delivery.

# %%
# Count of restaurants by rating text
sns.countplot(data=df, x='Rating text', palette='Set2')
plt.xticks(rotation=90)
plt.title('Rating Text')
# Out:
# Text(0.5, 1.0, 'Rating Text')

# %% [markdown]
# The rating for the food is average.

# %%
# Top 10 cities by restaurant count
sns.countplot(data=df, y='City', palette='Set2', order=df['City'].value_counts().index[:10])
plt.title('Top 10 Cities by Restaurant Count')
# Out:
# Text(0.5, 1.0, 'Top 10 Cities by Restaurant Count')

# %% [markdown]
# The maximum restaurants are in new delhi.

# %%
# Count of restaurants by rating color
sns.countplot(data=df, x='Rating color', palette='Set2')
plt.xticks(rotation=90)
plt.title('Rating Color')
# Out:
# Text(0.5, 1.0, 'Rating Color')

# %% [markdown]
# The maximum rating color is for the orange color.

# %%
# Count of restaurants by currency
sns.countplot(data=df, x='Currency', palette='Set2')
plt.xticks(rotation=90)
plt.title('Currency')
# Out:
# Text(0.5, 1.0, 'Currency')

# %% [markdown]
# The maximum money are in the form of indian rupee.

# %%
# Count of restaurants delivering now
sns.countplot(data=df, x='Is delivering now', palette='Set2')
plt.xticks(rotation=90)
plt.title('Is Delivering Now')
# Out:
# Text(0.5, 1.0, 'Is Delivering Now')

# %% [markdown]
# No food is delivering quikly.

# %%
# Count of restaurants with a switch to order menu
sns.countplot(data=df, x='Switch to order menu', palette='Set2')
plt.xticks(rotation=90)
plt.title('Switch to Order Menu')
# Out:
# Text(0.5, 1.0, 'Switch to Order Menu')

# %% [markdown]
# no person is switch to menu

# %%
df.hist(figsize=(10,15),color = 'green');

# %%
# Box Plot of Average Cost for Two vs. Price Range
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Price range', y='Average Cost for two', palette='Set2')
plt.title('Box Plot of Average Cost for Two vs. Price Range')
plt.xticks(rotation=90)
plt.show()

# %%
# Box Plot of Votes by Price Range
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Price range', y='Votes', palette='Set2')
plt.title('Box Plot of Votes by Price Range')
plt.xlabel('Price Range')
plt.ylabel('Votes')
plt.xticks(rotation=90)
plt.show()

# %%
# Box Plots of Aggregate Rating by Price Range
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Price range', y='Aggregate rating', palette='Set2')
plt.title('Box Plots of Aggregate Rating by Price Range')
plt.xlabel('Price Range')
plt.ylabel('Aggregate Rating')
plt.xticks(rotation=90)
plt.show()

# %%
df.drop('Switch to order menu', axis=1, inplace=True)

# %% [markdown]
# # checking for the outliers

# %%
#plt.figure(figsize= (20,15), facecolor='white')
#plotnumber = 1

#for column in numerical_col:
   # if plotnumber<10:
        #ax = plt.subplot(2,5, plotnumber)
        #sns.boxplot(df[column], palette = 'Set2_r')
       # plt.xlabel(column, fontsize=20)
       # plt.yticks(rotation = 0, fontsize = 20)
   # plotnumber+=1
#plt.tight_layout()
#plt.show()

# %%
numerical_col
# Out:
# ['Country Code',
#  'Restaurant ID',
#  'Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %%
from scipy.stats import zscore
out_features = df[['Country Code','Longitude','Latitude', 'Aggregate rating','Votes','Average Cost for two']]
z= np.abs(zscore(out_features))
z
# Out:
#       Country Code     Longitude  Latitude  Aggregate rating     Votes  \
# 0         0.308045  3.429892e-16  0.000000          0.000000  0.000000
# 1         0.079904  3.429892e-16  0.000000          0.000000  0.000000
# 2         0.200885  3.429892e-16  0.000000          0.000000  0.000000
# 3         0.323730  3.429892e-16  0.000000          0.000000  0.000000
# 4         1.324040  3.429892e-16  0.000000          0.000000  0.000000
# ...            ...           ...       ...               ...       ...
# 9546      3.324659  8.483509e-01  1.379106          0.946222  1.468303
# 9547      3.324659  8.468085e-01  1.377929          1.012224  2.040650
# 9548      3.324659  8.469691e-01  1.382109          0.682215  1.172823
# 9549      3.324659  8.469359e-01  1.382305          0.880221  1.731210
# 9550      3.324659  8.471773e-01  1.375650          0.880221  1.009960
#
#       Average Cost for two
# 0                 0.000000
# 1                 0.000000
# 2                 0.000000
# ...

# %%
#threshold=3
np.where(z>3)
# Out:
# (array([  10,   11,   12, ..., 9563, 9564, 9565], dtype=int64),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int64))

# %%
#so now removing the data above zscore and creating a new df
df1= df[(z<3).all(axis=1)]
df1.shape
# Out:
# (8575, 21)

# %%
print("Data loss percentage- ",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  10.359606941250261

# %%
#now using IQR method

#1st quantile
Q1 = out_features.quantile(0.25)

#3rd quantile
Q3 = out_features.quantile(0.75)

#IQR
IQR = Q3 - Q1

df2= df[~((df <(Q1 - 1.5 * IQR))|(df> (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (4704, 21)

# %%
print("Data loss percentage- ",((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  50.82584152205729

# %% [markdown]
# As we see that the zscore method will give the less amount of loss percentage data so we used df1 as our new dataframe

# %%
df=df1

# %% [markdown]
# Now checking how the data has been distributed in each column

# %%
plt.figure(figsize = (25,20))
plotnumber = 1

for column in numerical_col:
    if plotnumber <=10:
        ax = plt.subplot(2,5,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# As we can see the skewness in some of the columns.

# %%
#Checking for skewness
df.skew()
# Out:
# Country Code            11.096058
# Restaurant ID            0.117907
# Longitude               -3.529059
# Latitude                -3.182455
# Average Cost for two     3.711990
# Price range              1.029443
# Aggregate rating        -0.878128
# Votes                    3.654076
# dtype: float64

# %% [markdown]
# AS we can see the skewness in almost all the columns, lets remove these skewness.

# %%
df['Country Code']= np.log10(df['Country Code'])

# %%
df.skew()
# Out:
# Country Code            10.855460
# Restaurant ID            0.117907
# Longitude               -3.529059
# Latitude                -3.182455
# Average Cost for two     3.711990
# Price range              1.029443
# Aggregate rating        -0.878128
# Votes                    3.654076
# dtype: float64

# %%
df['Votes']= np.cbrt(df['Votes'])

# %%
df.skew()
# Out:
# Country Code            10.855460
# Restaurant ID            0.117907
# Longitude               -3.529059
# Latitude                -3.182455
# Average Cost for two     3.711990
# Price range              1.029443
# Aggregate rating        -0.878128
# Votes                    0.758626
# dtype: float64

# %%
df['Average Cost for two']= np.cbrt(df['Average Cost for two'])

# %%
df.skew()
# Out:
# Country Code            10.855460
# Restaurant ID            0.117907
# Longitude               -3.529059
# Latitude                -3.182455
# Average Cost for two     1.039593
# Price range              1.029443
# Aggregate rating        -0.878128
# Votes                    0.758626
# dtype: float64

# %%
df['Average Cost for two']= np.cbrt(df['Average Cost for two'])

# %%
df.skew()
# Out:
# Country Code            10.855460
# Restaurant ID            0.117907
# Longitude               -3.529059
# Latitude                -3.182455
# Average Cost for two    -1.062323
# Price range              1.029443
# Aggregate rating        -0.878128
# Votes                    0.758626
# dtype: float64

# %%
df['Country Code']= np.cbrt(df['Country Code'])

# %%
df.skew()
# Out:
# Country Code            10.791331
# Restaurant ID            0.117907
# Longitude               -3.529059
# Latitude                -3.182455
# Average Cost for two    -1.062323
# Price range              1.029443
# Aggregate rating        -0.878128
# Votes                    0.758626
# dtype: float64

# %% [markdown]
# As we cannot remove the skewness from the column Average cost for two, as it is our target value.

# %% [markdown]
# # Encoding the categorical columns using Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for i in df.columns:
    if df[i].dtypes==object:
        df[i]=le.fit_transform(df[i])
df
# Out:
#       Country Code  Country  Restaurant ID  Restaurant Name  City  Address  \
# 0         0.000000        3   9.051128e+06              972    35     3802
# 1         1.046512        0   9.051128e+06              972    35     3802
# 2         1.138864        1   9.051128e+06              972    35     3802
# 3         1.161807        2   9.051128e+06              972    35     3802
# 4         1.254253        4   9.051128e+06              972    35     3802
# ...            ...      ...            ...              ...   ...      ...
# 9432      1.304542        0   6.201972e+06             1947    13     1344
# 9433      1.304542        0   6.201130e+06             6352    13      835
# 9434      1.304542        0   1.826120e+07             4824    13     4700
# 9435      1.304542        0   6.201360e+06             4253    13     3211
# 9436      1.304542        0   1.831880e+07             4767    13     7592
#
#       Locality  Locality Verbose  Longitude   Latitude  ...  \
# ...

# %% [markdown]
# we save these data for our price range model predicting

# %%
price_df=df

# %%
price_df.shape
# Out:
# (8575, 21)

# %% [markdown]
# # Correlation between target variable and independent variable

# %%
#checking correlation between features
df.corr()
# Out:
#                       Country Code   Country  Restaurant ID  Restaurant Name  \
# Country Code              1.000000  0.290366       0.034951        -0.001038
# Country                   0.290366  1.000000       0.000803        -0.034225
# Restaurant ID             0.034951  0.000803       1.000000         0.002892
# Restaurant Name          -0.001038 -0.034225       0.002892         1.000000
# City                      0.024493  0.012510       0.010798         0.007920
# Address                  -0.021662 -0.003091       0.145529         0.001977
# Locality                 -0.043295 -0.042660       0.090445         0.010696
# Locality Verbose         -0.042149 -0.041327       0.090543         0.010611
# Longitude                 0.089301 -0.013784      -0.159266         0.016702
# Latitude                 -0.147642 -0.002026      -0.145941         0.012093
# Cuisines                 -0.013152  0.015435      -0.059933         0.060027
# ...

# %% [markdown]
# This gives the correlation between independent variable and target variable. Lets visualize this by plotting heatmap

# %%
#visualizing the correlation using the heatmap

plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True, fmt='0.2f', linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=15)
plt.title('Descriptive graph', fontsize=25)
plt.show()

# %% [markdown]
# from the above heatmap we can observed that:
# 1) the target variable is strongly related to the price range..
# 2) the column votes is strongly related to aggregate rating.
# 3) The column longitude and latitude and the column locality and locality verbose is strongly related to each other.

# %%
#visualizing the correlation between target and label using bar plot
plt.figure(figsize=(22,8))
df.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind="bar",color="g")
plt.xlabel("Feature", fontsize = 17)
plt.ylabel("Target", fontsize= 17)
plt.title("correlation between label and feature", fontsize = 23)
plt.show()

# %% [markdown]
# As we can see that the column is delivering now and cuisins are less related to the target variable.

# %% [markdown]
# # Seprating Feature and Label variable

# %%
x=df.drop("Average Cost for two", axis=1)
y=df1["Average Cost for two"]

# %% [markdown]
# # Feature scaling using standard scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x= pd.DataFrame(scaler.fit_transform(x), columns= x.columns)
x
# Out:
#       Country Code    Country  Restaurant ID  Restaurant Name      City  \
# 0        -0.091975  16.433707       0.027878        -1.188487  0.434417
# 1         8.741543  -0.028797       0.027878        -1.188487  0.434417
# 2         9.521079   5.458704       0.027878        -1.188487  0.434417
# 3         9.714734  10.946205       0.027878        -1.188487  0.434417
# 4        10.495061  21.921208       0.027878        -1.188487  0.434417
# ...            ...        ...            ...              ...       ...
# 8570     10.919547  -0.028797      -0.290506        -0.672741 -2.132545
# 8571     10.919547  -0.028797      -0.290600         1.657374 -2.132545
# 8572     10.919547  -0.028797       1.057073         0.849107 -2.132545
# 8573     10.919547  -0.028797      -0.290574         0.547065 -2.132545
# 8574     10.919547  -0.028797       1.063509         0.818956 -2.132545
#
#        Address  Locality  Locality Verbose  Longitude  Latitude  Cuisines  \
# ...

# %% [markdown]
# We have scaled the data using standard scalarization to overcome the issue of biasness

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#     VIF values             Features
# 0     1.509508         Country Code
# 1     1.150281              Country
# 2     1.448880        Restaurant ID
# 3     1.010840      Restaurant Name
# 4     1.080390                 City
# 5     1.064609              Address
# 6   511.602153             Locality
# 7   511.482105     Locality Verbose
# 8     8.350538            Longitude
# 9     8.510859             Latitude
# 10    1.029235             Cuisines
# 11    1.455300             Currency
# 12    1.593674    Has Table booking
# 13    1.230349  Has Online delivery
# 14    1.015854    Is delivering now
# 15    2.002378          Price range
# 16    3.494166     Aggregate rating
# 17    1.236098         Rating color
# 18    1.644447          Rating text
# 19    3.998682                Votes

# %% [markdown]
# As we can see that locality and locality verbose have high multicolinerity value so we drop one of the column.

# %%
#dropping locality verbose column
x.drop('Locality Verbose', axis=1, inplace=True)

# %%
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#     VIF values             Features
# 0     1.508632         Country Code
# 1     1.149951              Country
# 2     1.448572        Restaurant ID
# 3     1.010836      Restaurant Name
# 4     1.073811                 City
# 5     1.063283              Address
# 6     1.058197             Locality
# 7     8.342060            Longitude
# 8     8.503123             Latitude
# 9     1.028640             Cuisines
# 10    1.455265             Currency
# 11    1.593020    Has Table booking
# 12    1.229344  Has Online delivery
# 13    1.015849    Is delivering now
# 14    1.998887          Price range
# 15    3.492626     Aggregate rating
# 16    1.236038         Rating color
# 17    1.644423          Rating text
# 18    3.991867                Votes

# %% [markdown]
# As we can see that we solve the problem of multicolinerity, so now we are proceeding for our model building

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# Finding the best random State

# %%
# creating train test split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=10, random_state=i)
    lr= LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is", maxAccu,"On Random State", maxRs)
# Out:
# Maximum r2 score is 0.9558493287976387 On Random State 78

# %% [markdown]
# The maximum R2 score for this model is 95.58% at random state 175.

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.40, random_state = maxRs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR= LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_LR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.703740785714247
# R2_score on training data: 72.11410732143635
# Mean Absolute Error: 0.05718552075889909
# Mean Squared Error: 0.009149065593659866
# Root Mean Squared Error: 0.09565074800366104

# %% [markdown]
# The R2 score for this model is 70.37%

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_RFR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.6990845488129884
# R2_score on training data: 97.28081632070914
# Mean Absolute Error: 0.05718552075889909
# Mean Squared Error: 0.009292859321500323
# Root Mean Squared Error: 0.09639947780719729

# %% [markdown]
# The R2 score for this model is 71%

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print("R2_score:" , r2_score(y_test,pred_knn))
print("R2_score on training data: ", r2_score(y_train,pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:", mean_squared_error(y_test, pred_knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# R2_score: 0.6268304139944474
# R2_score on training data:  76.34504718606638
# Mean Aboslute Error: 0.06582364392802491
# Mean Squared Error: 0.011524208717540915
# Root Mean Squared Error: 0.107350867334833

# %% [markdown]
# The R2 score for this model is 62.68%

# %%
gbr= GradientBoostingRegressor()
gbr.fit(x_train, y_train)
pred_gbr = gbr.predict(x_test)
pred_train = gbr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_gbr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_gbr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_gbr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_gbr)))
# Out:
# R2_score: 0.71885515569037
# R2_score on training Data: 88.07898500763585
# Mean Aboslute Error: 0.05072912014183473
# Mean Squared Error: 0.008682304204814037
# Root Mean Squared Error: 0.0931788828266042

# %% [markdown]
# The R2 score for this model is 72%

# %%
lasso= Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print("R2_score:", r2_score(y_test, pred_lasso))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:", mean_squared_error(y_test, pred_lasso))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_score: -1.0056262805369087e-05
# R2_score on training Data: 0.0
# Mean Aboslute Error: 0.1261571092490016
# Mean Squared Error: 0.030882271868321355
# Root Mean Squared Error: 0.17573352516899374

# %%
rd= Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print("R2_score:", r2_score(y_test, pred_rd))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:", mean_squared_error(y_test, pred_rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_rd)))
# Out:
# R2_score: 0.7037426717459061
# R2_score on training Data: 72.11409868939324
# Mean Aboslute Error: 0.0571803737087162
# Mean Squared Error: 0.00914900734930314
# Root Mean Squared Error: 0.09565044353950032

# %% [markdown]
# The R2 score for this model is 70.37%

# %%
tr= ExtraTreesRegressor()
tr.fit(x_train, y_train)
pred_tr = tr.predict(x_test)
pred_train = tr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_tr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_tr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_tr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_tr)))
# Out:
# R2_score: 0.7336559467100873
# R2_score on training Data: 100.0
# Mean Aboslute Error: 0.04983151830377895
# Mean Squared Error: 0.008225226749167933
# Root Mean Squared Error: 0.09069303583609897

# %% [markdown]
# The R2 score for this model is 72.82%

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()
xgb.fit(x_train,y_train)
pred_xgb = xgb.predict(x_test)
pred_train = xgb.predict(x_train)
print("R2_score:", r2_score(y_test, pred_xgb))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_xgb))
print("Mean Squared Error:", mean_squared_error(y_test, pred_xgb))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_xgb)))
# Out:
# R2_score: 0.6790841970056005
# R2_score on training Data: 98.14334214928286
# Mean Aboslute Error: 0.05079820814970037
# Mean Squared Error: 0.009910509412226515
# Root Mean Squared Error: 0.09955154148593841

# %% [markdown]
# The R2 score for this model is 67.9%

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada.fit(x_train, y_train)
pred_ada = ada.predict(x_test)
pred_train = ada.predict(x_train)
print("R2_score:", r2_score(y_test, pred_ada))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_ada))
print("Mean Squared Error:", mean_squared_error(y_test, pred_ada))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_ada)))
# Out:
# R2_score: 0.6898636039496979
# R2_score on training Data: 79.11711127749442
# Mean Aboslute Error: 0.06620075898625152
# Mean Squared Error: 0.009577620184021193
# Root Mean Squared Error: 0.09786531655301174

# %% [markdown]
# The R2 score for this model is 66.59%

# %% [markdown]
# # Cross validation of the models

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between cross validation score and R2 score at LinearRegression is:",(r2_score(y_test,pred_LR)- score.mean())*100)
# Out:
# [0.51420436 0.72954469 0.76621707 0.82754058 0.46428105]
# 0.66035755026773
# Difference between cross validation score and R2 score at LinearRegression is: 4.338323544651701

# %%
score1= cross_val_score(RFR,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between cross validation score and R2 score at RandomForestRegressor is:",(r2_score(y_test,pred_RFR)- score.mean())*100)
# Out:
# [-20.91688166   0.76881276   0.8351129    0.88387892   0.60940928]
# -3.5639335610998706
# Difference between cross validation score and R2 score at RandomForestRegressor is: 3.8726998545258406

# %%
score3= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between cross validation score and R2 score at knn is:",(r2_score(y_test,pred_knn)- score.mean())*100)
# Out:
# [0.41263939 0.65667911 0.71432287 0.77150962 0.4734857 ]
# 0.6057273389013349
# Difference between cross validation score and R2 score at knn is: -3.352713627328263

# %%
score4= cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print("Difference between cross validation score and R2 score at GradientBoostingRegressor is:",(r2_score(y_test,pred_gbr)- score.mean())*100)
# Out:
# [-20.68838143   0.76018394   0.82141453   0.86808118   0.5804535 ]
# -3.5316496573963567
# Difference between cross validation score and R2 score at GradientBoostingRegressor is: 5.849760542263994

# %%
score5= cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print("Difference between cross validation score and R2 score at lasso is:",(r2_score(y_test,pred_lasso)- score.mean())*100)
# Out:
# [-3.41085991e-02 -2.55208615e-02 -8.40191862e-02 -2.08812068e-05
#  -1.96494991e-02]
# -0.03266380542587375
# Difference between cross validation score and R2 score at lasso is: -66.03676065305353

# %%
score6= cross_val_score(rd,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print("Difference between cross validation score and R2 score at Ridge is:",(r2_score(y_test,pred_rd)- score.mean())*100)
# Out:
# [0.51480937 0.72957092 0.7662129  0.8275201  0.46621631]
# 0.660865918292569
# Difference between cross validation score and R2 score at Ridge is: 4.3385121478176085

# %%
score8= cross_val_score(tr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print("Difference between cross validation score and R2 score at ExtraTreesRegressor is:",(r2_score(y_test,pred_tr)- score.mean())*100)
# Out:
# [-7.85106225  0.76786632  0.8188177   0.87383968  0.65902027]
# -0.9463036575184918
# Difference between cross validation score and R2 score at ExtraTreesRegressor is: 7.329839644235725

# %%
score9= cross_val_score(xgb,x,y,cv=5,scoring='r2')
print(score9)
print(score9.mean())
print("Difference between cross validation score and R2 score at xgbregressor is:",(r2_score(y_test,pred_xgb)- score.mean())*100)
# Out:
# [-27.17725745   0.75858484   0.8290101    0.8802276    0.40226729]
# -4.8614335227485
# Difference between cross validation score and R2 score at xgbregressor is: 1.87266467378705

# %%
score10= cross_val_score(ada,x,y,cv=5,scoring='r2')
print(score10)
print(score10.mean())
print("Difference between cross validation score and R2 score at AdaBoostRegressor is:",(r2_score(y_test,pred_ada)- score.mean())*100)
# Out:
# [-31.44339986   0.62326843   0.71001859   0.76173399   0.51073736]
# -5.767528299274466
# Difference between cross validation score and R2 score at AdaBoostRegressor is: 2.9506053681967903

# %% [markdown]
# # conclusion

# %% [markdown]
# From the differnece between R2 score and cross validation score we can conclude that ADA boost Regressor is our best fitted model.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters= {'n_estimators':[10, 25, 50, 100],
            'learning_rate':[1.0, 5.0, 2.5, 5.5],
            'loss':['linear', 'square', 'exponential'],
            'random_state':[5,10,50,100]}

# %%
GCV=GridSearchCV(AdaBoostRegressor(),parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [1.0, 5.0, 2.5, 5.5],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [10, 25, 50, 100],
#                          'random_state': [5, 10, 50, 100]})

# %%
GCV.best_params_
# Out:
# {'learning_rate': 1.0,
#  'loss': 'linear',
#  'n_estimators': 25,
#  'random_state': 10}

# %%
Final_model = AdaBoostRegressor(learning_rate= 1.0, loss='linear', n_estimators=25, random_state=10)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print('R2_score:', r2_score(y_test, pred))
print("Mean_absolute_error:", mean_absolute_error(y_test,pred))
print("Mean Squared Error:", mean_squared_error(y_test,pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.7121774147008844
# Mean_absolute_error: 0.06171839123568184
# Mean Squared Error: 0.008888525943697559
# Root Mean Squared Error: 0.09427897933101291

# %% [markdown]
# So the best R2 score for the final model is 71.21%

# %% [markdown]
# # Saving the model

# %%
#saving the model using.pkl
import joblib
joblib.dump(Final_model, "Zomato food_cost.pkl")
# Out:
# ['Zomato food_cost.pkl']

# %%
import pickle
filename='Zomato food_cost.pkl'
pickle.dump(Final_model,open(filename,'wb'))

# %%
import pickle
loaded_model= pickle.load(open('Zomato food_cost.pkl', 'rb'))
result= loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 71.21774147008844

# %%
conclusion= pd.DataFrame([loaded_model.predict(x_test)[:], y_test[:]], index=["Predicted", "Original"])
conclusion
# Out:
#                0         1         2         3         4         5     \
# Predicted  2.037363  2.183736  1.846726  2.361510  2.361510  1.846726
# Original   2.015973  2.198524  1.744970  2.415558  2.385332  1.884672
#
#                6         7         8         9     ...      3420      3421  \
# Predicted  2.079653  1.846726  2.037363  2.037363  ...  2.037363  1.846726
# Original   2.198524  1.801648  2.035558  1.994737  ...  2.035558  1.917230
#
#                3422      3423      3424      3425      3426      3427  \
# Predicted  2.079653  1.846726  2.183736  2.361510  1.794042  2.183736
# Original   2.142191  1.668101  2.299836  2.546317  1.668101  2.177371
#
#                3428      3429
# Predicted  2.183736  2.032436
# Original   2.253715  2.035558
#
# [2 rows x 3430 columns]

# %% [markdown]
# As we observed that there is not much of difference between original and predicted value.

# %% [markdown]
# # Predicting model for Price Range

# %% [markdown]
# we already saved our data for price range model

# %%
df=price_df

# %% [markdown]
# # Correlation between target variable and independent variable

# %%
#checking correlation between features
df.corr()
# Out:
#                       Country Code   Country  Restaurant ID  Restaurant Name  \
# Country Code              1.000000  0.290366       0.034951        -0.001038
# Country                   0.290366  1.000000       0.000803        -0.034225
# Restaurant ID             0.034951  0.000803       1.000000         0.002892
# Restaurant Name          -0.001038 -0.034225       0.002892         1.000000
# City                      0.024493  0.012510       0.010798         0.007920
# Address                  -0.021662 -0.003091       0.145529         0.001977
# Locality                 -0.043295 -0.042660       0.090445         0.010696
# Locality Verbose         -0.042149 -0.041327       0.090543         0.010611
# Longitude                 0.089301 -0.013784      -0.159266         0.016702
# Latitude                 -0.147642 -0.002026      -0.145941         0.012093
# Cuisines                 -0.013152  0.015435      -0.059933         0.060027
# ...

# %% [markdown]
# This gives the correlation between independent variable and target variable. Lets visualize this by plotting heatmap

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True, fmt='0.2f', linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=15)
plt.title('Descriptive graph', fontsize=25)
plt.show()

# %% [markdown]
# As we can observed that:
# 1) the target variable is strongly related to Average cost for two.
# 2) and its not related to the column country.
# 3) Price range is also related to the  table booking.
#
# 4) The votes and aggregate rating are strongly related to each other.

# %%
#visualizing the correlation between target and label using bar plot
plt.figure(figsize=(22,8))
df.corr()['Price range'].sort_values(ascending=False).drop(['Price range']).plot(kind="bar",color="g")
plt.xlabel("Feature", fontsize = 17)
plt.ylabel("Target", fontsize= 17)
plt.title("correlation between label and feature", fontsize = 23)
plt.show()

# %% [markdown]
# As we can see that the column country has very less relation to country.

# %% [markdown]
# # Seprating Feature and Label variable

# %%
x=df1.drop("Price range", axis=1)
y=df1["Price range"]

# %% [markdown]
# # Feature scaling using standard scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x= pd.DataFrame(scaler.fit_transform(x), columns= x.columns)
x
# Out:
#       Country Code    Country  Restaurant ID  Restaurant Name      City  \
# 0        -0.091975  16.433707       0.027878        -1.188487  0.434417
# 1         8.741543  -0.028797       0.027878        -1.188487  0.434417
# 2         9.521079   5.458704       0.027878        -1.188487  0.434417
# 3         9.714734  10.946205       0.027878        -1.188487  0.434417
# 4        10.495061  21.921208       0.027878        -1.188487  0.434417
# ...            ...        ...            ...              ...       ...
# 8570     10.919547  -0.028797      -0.290506        -0.672741 -2.132545
# 8571     10.919547  -0.028797      -0.290600         1.657374 -2.132545
# 8572     10.919547  -0.028797       1.057073         0.849107 -2.132545
# 8573     10.919547  -0.028797      -0.290574         0.547065 -2.132545
# 8574     10.919547  -0.028797       1.063509         0.818956 -2.132545
#
#        Address  Locality  Locality Verbose  Longitude  Latitude  Cuisines  \
# ...

# %% [markdown]
# We have scaled the data using standard scalarization to overcome the issue of biasness

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#     VIF values              Features
# 0     1.505299          Country Code
# 1     1.155381               Country
# 2     1.454026         Restaurant ID
# 3     1.009821       Restaurant Name
# 4     1.076642                  City
# 5     1.066923               Address
# 6   510.875065              Locality
# 7   510.771198      Locality Verbose
# 8     8.269278             Longitude
# 9     8.369424              Latitude
# 10    1.027932              Cuisines
# 11    1.744937  Average Cost for two
# 12    1.448139              Currency
# 13    1.503814     Has Table booking
# 14    1.231618   Has Online delivery
# 15    1.015733     Is delivering now
# 16    3.478117      Aggregate rating
# 17    1.237586          Rating color
# 18    1.636993           Rating text
# 19    4.019809                 Votes

# %%
x.drop('Locality', axis=1, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#     VIF values              Features
# 0     1.503825          Country Code
# 1     1.155097               Country
# 2     1.453728         Restaurant ID
# 3     1.009818       Restaurant Name
# 4     1.069980                  City
# 5     1.065972               Address
# 6     1.058007      Locality Verbose
# 7     8.262995             Longitude
# 8     8.364221              Latitude
# 9     1.027450              Cuisines
# 10    1.744343  Average Cost for two
# 11    1.447977              Currency
# 12    1.503745     Has Table booking
# 13    1.230501   Has Online delivery
# 14    1.015732     Is delivering now
# 15    3.477109      Aggregate rating
# 16    1.237492          Rating color
# 17    1.636918           Rating text
# 18    4.010507                 Votes

# %% [markdown]
# As we can see that all the values are more than 10, so there is no problem of multicollinerity

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# Finding the best random State

# %%
# creating train test split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=10, random_state=i)
    lr= LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is", maxAccu,"On Random State", maxRs)
# Out:
# Maximum r2 score is 0.9445121851705177 On Random State 157

# %% [markdown]
# The best R2 score for this model is 94.45% at random state 157

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.40, random_state = maxRs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR= LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_LR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.7446420583419835
# R2_score on training data: 75.41262725323334
# Mean Absolute Error: 0.3152056194059871
# Mean Squared Error: 0.18129276773734138
# Root Mean Squared Error: 0.4257848843457708

# %% [markdown]
# The R2 score for this model is 74.46%

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_RFR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.9880861195426363
# R2_score on training data: 99.7625593970492
# Mean Absolute Error: 0.3152056194059871
# Mean Squared Error: 0.008458324611262362
# Root Mean Squared Error: 0.09196915032369475

# %% [markdown]
# The R2 score for this model is 98.80%

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print("R2_score:" , r2_score(y_test,pred_knn))
print("R2_score on training data: ", r2_score(y_train,pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:", mean_squared_error(y_test, pred_knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# R2_score: 0.7464038524152203
# R2_score on training data:  82.61436254628045
# Mean Aboslute Error: 0.28763707370559094
# Mean Squared Error: 0.18004197239631328
# Root Mean Squared Error: 0.4243135307721323

# %% [markdown]
# The R2 score for this model is 74.64%

# %%
gbr= GradientBoostingRegressor()
gbr.fit(x_train, y_train)
pred_gbr = gbr.predict(x_test)
pred_train = gbr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_gbr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_gbr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_gbr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_gbr)))
# Out:
# R2_score: 0.9835357310447593
# R2_score on training Data: 99.02745354267532
# Mean Aboslute Error: 0.03699887820937423
# Mean Squared Error: 0.011688897820397445
# Root Mean Squared Error: 0.10811520624036863

# %% [markdown]
# The R2 score for this model is 98.35%

# %%
lasso= Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print("R2_score:", r2_score(y_test, pred_lasso))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:", mean_squared_error(y_test, pred_lasso))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_score: -0.0005267982129588678
# R2_score on training Data: 0.0
# Mean Aboslute Error: 0.7053776821787944
# Mean Squared Error: 0.7103294742496346
# Root Mean Squared Error: 0.8428104616398842

# %%
rd= Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print("R2_score:", r2_score(y_test, pred_rd))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:", mean_squared_error(y_test, pred_rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_rd)))
# Out:
# R2_score: 0.7446637627376813
# R2_score on training Data: 75.412617831768
# Mean Aboslute Error: 0.3152138141533076
# Mean Squared Error: 0.18127735858287142
# Root Mean Squared Error: 0.4257667889618346

# %% [markdown]
# The R2 score for this model is 74.46%

# %%
tr= ExtraTreesRegressor()
tr.fit(x_train, y_train)
pred_tr = tr.predict(x_test)
pred_train = tr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_tr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_tr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_tr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_tr)))
# Out:
# R2_score: 0.9862782227073899
# R2_score on training Data: 100.0
# Mean Aboslute Error: 0.02687955468769316
# Mean Squared Error: 0.009741850860406135
# Root Mean Squared Error: 0.09870081489231046

# %% [markdown]
# The R2 score for this model is 98.62%

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()
xgb.fit(x_train,y_train)
pred_xgb = xgb.predict(x_test)
pred_train = xgb.predict(x_train)
print("R2_score:", r2_score(y_test, pred_xgb))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_xgb))
print("Mean Squared Error:", mean_squared_error(y_test, pred_xgb))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_xgb)))
# Out:
# R2_score: 0.9890373652235793
# R2_score on training Data: 99.9985207113045
# Mean Aboslute Error: 0.01912039254219122
# Mean Squared Error: 0.00778298253583433
# Root Mean Squared Error: 0.088221213638412

# %% [markdown]
# The R2 score for this model is 98.90%

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada.fit(x_train, y_train)
pred_ada = ada.predict(x_test)
pred_train = ada.predict(x_train)
print("R2_score:", r2_score(y_test, pred_ada))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_ada))
print("Mean Squared Error:", mean_squared_error(y_test, pred_ada))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_ada)))
# Out:
# R2_score: 0.9105308814108631
# R2_score on training Data: 91.31432953296226
# Mean Aboslute Error: 0.20684081208310862
# Mean Squared Error: 0.06351909022578006
# Root Mean Squared Error: 0.2520299391456897

# %% [markdown]
# The R2 score for this model is 91.05%

# %% [markdown]
# # Cross validation of the models

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between cross validation score and R2 score at LinearRegression is:",(r2_score(y_test,pred_LR)- score.mean())*100)
# Out:
# [0.10143734 0.75727585 0.76512516 0.82341792 0.52106496]
# 0.593664247653321
# Difference between cross validation score and R2 score at LinearRegression is: 15.097781068866245

# %%
score1= cross_val_score(RFR,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between cross validation score and R2 score at RandomForestRegressor is:",(r2_score(y_test,pred_RFR)- score.mean())*100)
# Out:
# [0.50843935 0.97707508 0.99991496 0.99950901 0.91944778]
# 0.8808772354909189
# Difference between cross validation score and R2 score at RandomForestRegressor is: 39.44218718893152

# %%
score3= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between cross validation score and R2 score at knn is:",(r2_score(y_test,pred_knn)- score.mean())*100)
# Out:
# [0.66666177 0.71667296 0.7492302  0.80081496 0.58482286]
# 0.7036405478954331
# Difference between cross validation score and R2 score at knn is: 15.273960476189929

# %%
score4= cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print("Difference between cross validation score and R2 score at GradientBoostingRegressor is:",(r2_score(y_test,pred_gbr)- score.mean())*100)
# Out:
# [0.02039191 0.97150749 0.99922614 0.99920124 0.91827952]
# 0.7817212587794847
# Difference between cross validation score and R2 score at GradientBoostingRegressor is: 38.98714833914383

# %%
score5= cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print("Difference between cross validation score and R2 score at lasso is:",(r2_score(y_test,pred_lasso)- score.mean())*100)
# Out:
# [-0.08829253 -0.02858399 -0.13532109 -0.00546316 -0.01096268]
# -0.053724689530096105
# Difference between cross validation score and R2 score at lasso is: -59.41910458662799

# %%
score6= cross_val_score(rd,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print("Difference between cross validation score and R2 score at Ridge is:",(r2_score(y_test,pred_rd)- score.mean())*100)
# Out:
# [0.15585375 0.75730163 0.76510131 0.82338939 0.52276298]
# 0.6048818124760734
# Difference between cross validation score and R2 score at Ridge is: 15.099951508436027

# %%
score8= cross_val_score(tr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print("Difference between cross validation score and R2 score at ExtraTreesRegressor is:",(r2_score(y_test,pred_tr)- score.mean())*100)
# Out:
# [0.8431425  0.97786431 0.99764173 0.99891944 0.9204235 ]
# 0.9475982947829118
# Difference between cross validation score and R2 score at ExtraTreesRegressor is: 39.26139750540688

# %%
score9= cross_val_score(xgb,x,y,cv=5,scoring='r2')
print(score9)
print(score9.mean())
print("Difference between cross validation score and R2 score at xgbregressor is:",(r2_score(y_test,pred_xgb)- score.mean())*100)
# Out:
# [0.55973205 0.9739836  0.99978112 0.99967522 0.95937987]
# 0.8985103727841606
# Difference between cross validation score and R2 score at xgbregressor is: 39.537311757025826

# %%
score10= cross_val_score(ada,x,y,cv=5,scoring='r2')
print(score10)
print(score10.mean())
print("Difference between cross validation score and R2 score at AdaBoostRegressor is:",(r2_score(y_test,pred_ada)- score.mean())*100)
# Out:
# [0.75552821 0.73093775 0.62746004 0.858598   0.82033465]
# 0.7585717317362948
# Difference between cross validation score and R2 score at AdaBoostRegressor is: 31.686663375754208

# %% [markdown]
# # conclusion

# %% [markdown]
# From the differnece between R2 score and cross validation score we can conclude that Ridge is our best fitted model.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters ={'alpha' :[1.0, 5.0, 10.0, 100.0],
            'fit_intercept':[True, False],
            'max_iter':[10,50,100,150],
            'solver':['auto','svd','cholesky','lsqr']}

# %%
GCV=GridSearchCV(Ridge(),parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 5.0, 10.0, 100.0],
#                          'fit_intercept': [True, False],
#                          'max_iter': [10, 50, 100, 150],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr']})

# %%
GCV.best_params_
# Out:
# {'alpha': 100.0, 'fit_intercept': True, 'max_iter': 10, 'solver': 'svd'}

# %%
Final_model = Ridge(alpha=100.0, fit_intercept= True, max_iter= 10, solver= 'svd')
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print('R2_score:', r2_score(y_test, pred))
print("Mean_absolute_error:", mean_absolute_error(y_test,pred))
print("Mean Squared Error:", mean_squared_error(y_test,pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.7459960115217128
# Mean_absolute_error: 0.3163789650560017
# Mean Squared Error: 0.18033152126994687
# Root Mean Squared Error: 0.42465459054382876

# %% [markdown]
# So the best R2 score for the final model is 74.59%

# %% [markdown]
# # Saving the model

# %%
#saving the model using.pkl
import joblib
joblib.dump(Final_model, "Zomato food_price.pkl")
# Out:
# ['Zomato food_price.pkl']

# %%
import pickle
filename='Zomato food_price.pkl'
pickle.dump(Final_model,open(filename,'wb'))

# %%
import pickle
loaded_model= pickle.load(open('Zomato food_price.pkl', 'rb'))
result= loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 74.59960115217127

# %%
conclusion= pd.DataFrame([loaded_model.predict(x_test)[:], y_test[:]], index=["Predicted", "Original"])
conclusion
# Out:
#               0         1         2         3         4        5         6     \
# Predicted  1.14352  2.957862  1.036209  1.201237  1.008236  1.84722  2.884138
# Original   1.00000  3.000000  1.000000  1.000000  1.000000  2.00000  3.000000
#
#                7         8         9     ...     3420      3421      3422  \
# Predicted  1.035444  1.198461  3.460513  ...  1.21207  1.863999  1.458856
# Original   1.000000  1.000000  3.000000  ...  1.00000  2.000000  1.000000
#
#                3423      3424      3425      3426      3427      3428  \
# Predicted  1.760924  1.422371  2.117875  3.305683  2.123559  1.440062
# Original   2.000000  1.000000  2.000000  3.000000  2.000000  1.000000
#
#                3429
# Predicted  1.868623
# Original   2.000000
#
# [2 rows x 3430 columns]

# %% [markdown]
# # Concluding Remarks

# %% [markdown]
# Here we predict our model for zomato food, here in this dataset we predict our model for Average cost for two and for price range. Both is our regression problem. the best model for the Average cost for two people is ADA boost regressor, and for the price range Ridge is the best fitted model.
# For both the model the accuracy score is almost nearby.
