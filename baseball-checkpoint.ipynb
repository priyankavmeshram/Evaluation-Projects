# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# In the above dataframe there are 30 rows and 17 columns

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# This dataframe contains 30 rows and 17 columns out of which 1 is targate variable and the remaining are independent variable. As the target variable is not in a classification form so it will be a regression problem.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
#checking the types of the columns
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# As we can see that there are two types of datatypes(float and integer)in the dataframe.

# %% [markdown]
# @Checking the null values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# As we can see that there are no null values present in the dataset

# %%
#lets visualize the null values using the heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# From the above heatmap also we can observed that there are no null values present in the dataset.

# %% [markdown]
# ~Now checking the value counts of each column

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %%
# checking the unique values in each column
df.nunique().to_frame("No. of unique values")
# Out:
#      No. of unique values
# W                      24
# R                      28
# AB                     29
# H                      29
# 2B                     22
# 3B                     23
# HR                     27
# BB                     29
# SO                     29
# SB                     27
# RA                     30
# ER                     30
# ERA                    30
# CG                      9
# SHO                    12
# SV                     20
# E                      21

# %% [markdown]
# ~Checking duplicates values in the column

# %%
print("Total duplicates values are:", df.duplicated().sum())
# Out:
# Total duplicates values are: 0

# %% [markdown]
# As we can see that there are no duplicates values present in the dataset

# %% [markdown]
# ~Checking for the whitespaces in the columns

# %%
df.loc[df['W']==" "]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# As we can see that there are no whitespaces present in the dataset

# %% [markdown]
# ~Description of dataset

# %%
#statstical summary of the numerical columns
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # This gives the statstical summary of the numerical columns.The summary of the dataset looks perfect as there are no negative or invalid values are present in the dataset. From the above description we can observe the following:
#
# 1) The value counts of each column is similar, it means no values are missing in the dataset.
# 2) As we can see that the mean value in the columns W, R, 2B, BB, SO, RA, ER, ERA, SHO are less than the meadian(50%)values it means the data are skewed to the left side in these columns.
# 3) The mean value in the columns AB, H, HR, SV, E are more than the median value, it means the data are skewed to the right side in these columns.
# 4) AS we can observed that there are difference between the 75% and the max value, it means outliers are present in these columns.
# 5) We can also observed the standard deviation, minimum value, and 25% valur from the above description.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ~univariate analysis

# %%
# Checking how the data has been distriubted in each column
plt.figure(figsize=(20,25), facecolor='green')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# From the above distribution plot we can observed that some of the columns are normally distributed, some of them have skewness.
# 1) our target column 'W' is normally distributed.
# 2) In the column R the graph looks normal but it has some skewness in the right side.
# 3) the column BB SO ER ERA and SHO is also looks normal, but they also have a little bit skewness in them.
# 4) THe column AB is normally distributed and has no skewness in that.
# 5) The column H, HR, SV, E, and CG are not normally distributed, and they are skewed to the right side.
# 6) THe column 2B has little bit skewness to the left side.
# 7) THe column 3B is also normally distributed.

# %% [markdown]
# ~ bivariate analysis

# %%
#1st We will check Label wins and runs

plt.figure(figsize=(8,5))
plt.title("Comparison Between Wins and Runs")
sns.regplot(x='W',y='R',data=df)
plt.xlabel("Wins",fontsize=10)
plt.ylabel("Runs",fontsize=10)
plt.show()

# %% [markdown]
# From the above graph we can observed that there is a small linear relationship between Wins and Runs.

# %%
# comparison between all independent variable with target variable.
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=17:
        plt.subplot(5,4,p)
        sns.regplot(x='W',y=i,data=df,color='b')
        plt.xlabel("Wins")
        plt.ylabel(i)
    p+=1
    
plt.show()

# %% [markdown]
# From the above graph we can observed that:
# 1) The column SV and BB have strong relationship with the varibale win.
# 2) The column R, 2B, HR, and SHO have a relationship with the target variable, but not in the strong manner.
# 3) The column E, AB, and SB have little bit negative relation with the win column.
# 4) The column ERA, RA and ER and strong negative relation with the win column.
# 5) The column CG and H does not have any relation withe the win column.
# 6) WE can also observed that the column ER and ERA is strongly related, as the graph looks similar.

# %% [markdown]
# ~ As we can see that there is no relationship between the column CG and H to our target column, lets visualize it by using a scatter plot to see whether there is any relation between them.

# %%
#comparison between CG and W
plt.figure(figsize=(8,5))
plt.title("Comparison Between Wins and CG")
sns.scatterplot(x='W',y='CG',data=df)
plt.xlabel("Wins",fontsize=10)
plt.ylabel("CG",fontsize=10)
plt.show()

# %% [markdown]
# From the above sctter plot we can there is no relationship between CG and W

# %%
# comparison between H and w
plt.figure(figsize=(8,5))
plt.title("Comparison Between Wins and Hits")
sns.scatterplot(x='W',y='H',data=df)
plt.xlabel("Wins",fontsize=10)
plt.ylabel("Hits",fontsize=10)
plt.show()

# %% [markdown]
# WE can that there is no relationship between hits and run

# %% [markdown]
# So we can handle with these columns  later with the best feature selection method.

# %% [markdown]
# AS we can observed that there is strong relationship between ER and ERA, lets visualize it using a graph

# %%
plt.figure(figsize=(8,5))
plt.title("Comparison Between ER and ERA")
sns.scatterplot(x='ER',y='ERA',data=df,hue='W')
plt.xlabel("ER",fontsize=10)
plt.ylabel("ERA",fontsize=10)
plt.show()

# %% [markdown]
# From the above graph we can observed the strong relationship between them so we can drop one of the column to handle the problem of multicolinearity.

# %% [markdown]
# To decide which column we have to drop between ER and ERA, we can check their relationship with the Run Average(RA).

# %%
#visualizing relation between ER and RA
plt.figure(figsize=(8,5))
plt.title("Comparison Between ER and ERA")
sns.scatterplot(x='ER',y='RA',data=df,hue='W')
plt.xlabel("ER",fontsize=10)
plt.ylabel("RA",fontsize=10)
plt.show()

# %%
#visualizing relation between ERA and RA
plt.figure(figsize=(8,5))
plt.title("Comparison Between ER and ERA")
sns.scatterplot(x='ERA',y='RA',data=df,hue='W')
plt.xlabel("ERA",fontsize=10)
plt.ylabel("RA",fontsize=10)
plt.show()

# %% [markdown]
# From the above graphs we can observed that the column ERA have more multicolinerity, so we can drop the column ERA

# %%
df= df.drop('ERA', axis=1)

# %%
df.shape
# Out:
# (30, 16)

# %% [markdown]
# # Best Feature selection

# %% [markdown]
# As we can see that there are so many columns which dont have any relation with our target column, smoe will have high negative relation with the traget column, so we can find the best features column for our target column, for that we can use the feature selection method

# %%
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import chi2
x=df.drop('W',axis=1)
y=df.W

# %%
# Getting best features
spercentile=SelectPercentile(score_func=chi2,percentile=90)
spercentile=spercentile.fit(x,y)
bestf=spercentile.get_support(indices=True)

# %%
# Our new data frame containing the best features
feature=x.columns[bestf]
df1=x[ feature]
df1['W']=df['W']
df1
# Out:
#       R     H  3B   HR   BB    SO   SB   RA   ER  CG  SHO  SV    E    W
# 0   724  1497  42  139  383   973  104  641  601   2    8  56   88   95
# 1   696  1349  44  156  439  1264   70  700  653   2   12  45   86   83
# 2   669  1395  29  141  533  1157   86  640  584  11   10  38   79   81
# 3   622  1381  27  136  404  1231   68  701  643   7    9  37  101   76
# 4   689  1515  49  151  455  1259   83  803  746   7   12  35   86   74
# 5   891  1480  17  232  570  1151   88  670  609   7   10  34   88   93
# 6   764  1397  19  212  554  1227   63  698  652   3    4  48   93   87
# 7   713  1370  20  217  418  1331   44  693  646   0   10  43   77   81
# 8   644  1383  32  167  436  1310   87  642  604   1   12  60   95   80
# 9   748  1495  33  161  478  1148   71  753  694   3   10  40   97   78
# 10  751  1419  32  172  503  1233  101  733  680   5    9  45  119   88
# 11  729  1363  26  230  486  1392  121  618  572   5   13  39   85   86
# ...

# %%
df1.columns
# Out:
# Index(['R', 'H', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'CG', 'SHO', 'SV',
#        'E', 'W'],
#       dtype='object')

# %%
df=df1

# %% [markdown]
# The fetured column which were removed are AB, 2B, SHO

# %%
df.shape
# Out:
# (30, 14)

# %% [markdown]
# # Checking for the outliers

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=17:
        plt.subplot(5,4,p)
        sns.boxplot(df[i], palette='Set2_r')
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# From the boxplot we can observed that the outliers are present in the column R, SHO, SV and E.
# we can remove these outliers using zscore method or IQR technique.

# %%
from scipy.stats import zscore
out_features = df[['R','SHO','SV','E']]
z= np.abs(zscore(out_features))
z
# Out:
#            R       SHO        SV         E
# 0   0.619078  0.814629  1.671607  0.461470
# 1   0.134432  0.172800  0.249879  0.607197
# 2   0.332906  0.320914  0.654856  1.117242
# 3   1.146419  0.567771  0.784104  0.485758
# 4   0.013270  0.172800  1.042600  0.607197
# 5   3.509647  0.320914  1.171848  0.461470
# 6   1.311430  1.802057  0.637623  0.097152
# 7   0.428681  0.320914  0.008617  1.262970
# 8   0.765626  0.172800  2.188598  0.048576
# 9   1.034489  0.320914  0.396360  0.194303
# 10  1.086415  0.567771  0.249879  1.797303
# 11  0.705622  0.419657  0.525608  0.680061
# 12  0.471376  0.172800  0.379127  0.097152
# 13  0.557920  0.172800  0.249879  0.024288
# 14  0.099814  0.913371  1.947335  2.307348
# 15  0.713699  0.913371  2.447094  0.121439
# 16  0.151740  0.419657  1.413111  2.015894
# 17  0.013270  2.394514  0.637623  1.214394
# 18  0.575229  1.061486  0.396360  1.578712
# 19  0.834861  0.814629  1.042600  0.315742
# 20  0.090583  0.666514  0.896119  0.461470
# ...

# %%
#threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
#so now removing the data above zscore and creating a new df
df1= df[(z<3).all(axis=1)]
df1.shape
# Out:
# (29, 14)

# %%
print("Data loss percentage- ",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  3.3333333333333335

# %%
#now using IQR method

#1st quantile
Q1 = out_features.quantile(0.25)

#3rd quantile
Q3 = out_features.quantile(0.75)

#IQR
IQR = Q3 - Q1

df2= df[~((df <(Q1 - 1.5 * IQR))|(df> (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (21, 14)

# %%
print("Data loss percentage- ",((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage-  30.0

# %% [markdown]
# As we see that the zscore method will give the less amount of loss percentage data so we used df1 as our new dataframe

# %%
df=df1

# %%
df.shape
# Out:
# (29, 14)

# %% [markdown]
# Now checking how the data has been distributed in each column

# %%
plt.figure(figsize=(20,25), facecolor='blue')
p=1

for column in df:
    if p<= 15:
        ax=plt.subplot(3,5,p)
        sns.distplot(df[column], color='r')
        plt.xlabel(column, fontsize=25)
    p+=1
plt.show()

# %% [markdown]
# As we can see the skewness in some of the columns.

# %% [markdown]
# # Checking for skewness

# %%
df.skew()
# Out:
# R     -0.215364
# H      0.783772
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# W      0.119013
# dtype: float64

# %% [markdown]
# As we can see the skewness in the column H, CG, SV and E

# %%
# removing skewness using power transformer method
skewed_col=['H','CG','SV','E']
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
df[skewed_col] = scaler.fit_transform(df[skewed_col].values)
df[skewed_col].head()
# Out:
#               H        CG        SV         E
# 0  4.163336e-16 -0.307098  1.532753 -0.348265
# 1 -2.498002e-16 -0.307098  0.312020 -0.540820
# 2  0.000000e+00  2.011315 -0.664137 -1.326125
# 3 -8.326673e-17  1.264463 -0.820689  0.650818
# 4  4.718448e-16  1.264463 -1.149165 -0.540820

# %%
# now again check the skewness
df.skew()
# Out:
# R     -0.215364
# H      0.000000
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# CG    -0.045947
# SHO    0.526943
# SV    -0.000925
# E      0.065585
# W      0.119013
# dtype: float64

# %% [markdown]
# so now again we visualize it

# %%
plt.figure(figsize=(20,25), facecolor='blue')
p=1

for column in df:
    if p<= 15:
        ax=plt.subplot(3,5,p)
        sns.distplot(df[column], color='r')
        plt.xlabel(column, fontsize=25)
    p+=1
plt.show()

# %% [markdown]
# As we can see that we remove the skewness from the columns.

# %% [markdown]
# # Correlation between target variable and independent variable

# %%
#checking correlation between features
df.corr()
# Out:
#             R         H        3B        HR        BB        SO        SB  \
# R    1.000000  0.435073  0.134204  0.586894  0.258450  0.081158  0.075323
# H    0.435073  1.000000  0.566793 -0.221813 -0.209681 -0.380109  0.430001
# 3B   0.134204  0.566793  1.000000 -0.369299 -0.404852 -0.196586  0.483818
# HR   0.586894 -0.221813 -0.369299  1.000000  0.336814  0.479914 -0.166072
# BB   0.258450 -0.209681 -0.404852  0.336814  1.000000  0.315566 -0.117622
# SO   0.081158 -0.380109 -0.196586  0.479914  0.315566  1.000000  0.038188
# SB   0.075323  0.430001  0.483818 -0.166072 -0.117622  0.038188  1.000000
# RA  -0.013858  0.229856  0.312750 -0.092586 -0.425381 -0.140570  0.134315
# ER   0.007727  0.265399  0.333731 -0.062094 -0.455832 -0.177655  0.146243
# CG   0.155122  0.064183 -0.004496  0.118284  0.445335 -0.063129 -0.040524
# SHO -0.085108 -0.143595 -0.058896  0.005546  0.473922  0.231230 -0.104602
# SV   0.083261 -0.113963 -0.269255  0.106523  0.207948  0.125572 -0.195772
# ...

# %% [markdown]
# This gives the correlation between independent variable and target variable. Lets visualize this by plotting heatmap

# %%
plt.figure(figsize=(26,14))
sns.heatmap(df.corr(),annot=True, fmt='0.2f', linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=15)
plt.title('Descriptive graph', fontsize=25)
plt.show()

# %% [markdown]
# from the above heatmap we can observed that:
# 1) The column CG and H have very least relationship with the column wins.
# 2) The column ER and RA  have very strong negative relation with the column wins.
# 3) The column ER and RA are highly correlated to each other.

# %%
#visualizing the correlation between target and label using bar plot
plt.figure(figsize=(22,8))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind="bar",color="g")
plt.xlabel("Feature", fontsize = 17)
plt.ylabel("Target", fontsize= 17)
plt.title("correlation between label and feature", fontsize = 23)
plt.show()

# %% [markdown]
# From the above bar plot we can observed that the column SV is highly positively correlated to the target column and the column CG is least correlated to target variable.
# the column ER  and RA  is more negatively correlated to the target variable.

# %% [markdown]
# # Seprating Feature and Label variable

# %%
x=df1.drop("W", axis=1)
y=df1["W"]

# %% [markdown]
# # Feature scaling using standard scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x= pd.DataFrame(scaler.fit_transform(x), columns= x.columns)
x
# Out:
#            R         H        3B        HR        BB        SO        SB  \
# 0   0.959398  1.659631  1.010845 -0.765863 -1.536359 -2.727623  0.905953
# 1   0.331147 -0.959651  1.208917 -0.181389 -0.495021  0.121896 -0.585315
# 2  -0.274666  0.022580 -0.276617 -0.697101  1.252941 -0.925866  0.116458
# 3  -1.329231 -0.304830 -0.474688 -0.869006 -1.145857 -0.201246 -0.673037
# 4   0.174084  1.877905  1.704094 -0.353293 -0.197495  0.072935 -0.015124
# 5   1.856900  0.022580 -1.266972  1.743939  1.643442 -0.240414 -0.892341
# 6   0.712585 -0.523104 -1.167936  1.915843 -0.885522  0.777970 -1.725697
# 7  -0.835605 -0.304830  0.020490  0.196801 -0.550807  0.572335  0.160319
# 8   1.497899  1.659631  0.119526 -0.009484  0.230197 -1.013995 -0.541454
# 9   1.565212  0.459127  0.020490  0.368705  0.695081 -0.181661  0.774370
# 10  1.071586 -0.632241 -0.573723  2.362794  0.378960  1.375292  1.651587
# 11 -0.454167 -1.396198 -1.068901  0.506228 -0.569402 -0.994411 -1.374810
# ...

# %% [markdown]
# We have scaled the data using standard scalarization to overcome the issue of biasness

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#     VIF values Features
# 0     5.547698        R
# 1     3.537134        H
# 2     3.001281       3B
# 3     6.950756       HR
# 4     3.297668       BB
# 5     2.833437       SO
# 6     1.857396       SB
# 7   174.848892       RA
# 8   165.824807       ER
# 9     1.896571       CG
# 10    3.206852      SHO
# 11    2.711445       SV
# 12    1.704604        E

# %% [markdown]
# By checking VIF values we can find the feature causing the multicollinarity problem. here we can find that The column RA and ER have VIF value greater than 5.so we will drop one of the column first,if the same problem persist then we will trying to remove other higher vif value column.

# %%
#dropping ER column
x.drop("ER", axis=1, inplace=True)

# %%
#again checking vif values
vif= pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values, i) for  i in range(len(x.columns))]
vif["Features"]= x.columns
vif
# Out:
#     VIF values Features
# 0     5.216845        R
# 1     3.384434        H
# 2     2.921537       3B
# 3     5.058983       HR
# 4     2.880452       BB
# 5     2.268914       SO
# 6     1.785024       SB
# 7     4.014890       RA
# 8     1.816884       CG
# 9     3.044467      SHO
# 10    2.235448       SV
# 11    1.487148        E

# %% [markdown]
# AS we can see that we solved the problem of multicolineraity, so we move ahed for model building

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# ~Finding the best random State

# %%
# creating train test split
maxAccu=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state=i)
    lr= LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Maximum r2 score is", maxAccu,"On Random State", maxRs)
# Out:
# Maximum r2 score is 0.9407243329508492 On Random State 141

# %% [markdown]
# The best accuracy score is 94.07% at random state 141

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30, random_state = maxRs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR= LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_LR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.9407243329508492
# R2_score on training data: 90.25874964005061
# Mean Absolute Error: 2.309799512553269
# Mean Squared Error: 7.123325222918934
# Root Mean Squared Error: 2.668955830080171

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score:', r2_score(y_test, pred_RFR))
print('R2_score on training data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:", mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.5573777070063692
# R2_score on training data: 93.23869485531377
# Mean Absolute Error: 2.309799512553269
# Mean Squared Error: 53.19117777777779
# Root Mean Squared Error: 7.293228213745802

# %%
knn= KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print("R2_score:" , r2_score(y_test,pred_knn))
print("R2_score on training data: ", r2_score(y_train,pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:", mean_squared_error(y_test, pred_knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# R2_score: 0.5598561742346413
# R2_score on training data:  53.4360721753272
# Mean Aboslute Error: 6.333333333333333
# Mean Squared Error: 52.893333333333345
# Root Mean Squared Error: 7.272780302836965

# %%
lasso= Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print("R2_score:", r2_score(y_test, pred_lasso))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:", mean_squared_error(y_test, pred_lasso))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_score: 0.9414105416843688
# R2_score on training Data: 85.26631824409921
# Mean Aboslute Error: 2.171403169251456
# Mean Squared Error: 7.04086157091796
# Root Mean Squared Error: 2.6534621856958807

# %%
rd= Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print("R2_score:", r2_score(y_test, pred_rd))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:", mean_squared_error(y_test, pred_rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_rd)))
# Out:
# R2_score: 0.9494932871369773
# R2_score on training Data: 89.89338745524209
# Mean Aboslute Error: 2.1741836887865293
# Mean Squared Error: 6.069535098872374
# Root Mean Squared Error: 2.4636426483709797

# %%
from sklearn.tree import DecisionTreeRegressor
dtr= DecisionTreeRegressor()
dtr.fit(x_train, y_train)
pred_dtr = dtr.predict(x_test)
pred_train = rd.predict(x_train)
print("R2_score:", r2_score(y_test, pred_dtr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_dtr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_dtr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_dtr)))
# Out:
# R2_score: 0.19837682350523922
# R2_score on training Data: 89.89338745524209
# Mean Aboslute Error: 8.555555555555555
# Mean Squared Error: 96.33333333333333
# Root Mean Squared Error: 9.814954576223638

# %%
tr= ExtraTreesRegressor()
tr.fit(x_train, y_train)
pred_tr = tr.predict(x_test)
pred_train = tr.predict(x_train)
print("R2_score:", r2_score(y_test, pred_tr))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_tr))
print("Mean Squared Error:", mean_squared_error(y_test, pred_tr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_tr)))
# Out:
# R2_score: 0.49988255598931586
# R2_score on training Data: 100.0
# Mean Aboslute Error: 6.45111111111111
# Mean Squared Error: 60.100533333333324
# Root Mean Squared Error: 7.752453375115088

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()
xgb.fit(x_train,y_train)
pred_xgb = xgb.predict(x_test)
pred_train = xgb.predict(x_train)
print("R2_score:", r2_score(y_test, pred_xgb))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_xgb))
print("Mean Squared Error:", mean_squared_error(y_test, pred_xgb))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_xgb)))
# Out:
# R2_score: 0.5598240585851662
# R2_score on training Data: 99.99999973337079
# Mean Aboslute Error: 5.724198235405816
# Mean Squared Error: 52.89719276212337
# Root Mean Squared Error: 7.273045631791634

# %%
from sklearn.linear_model import SGDRegressor
SGD=SGDRegressor()
SGD.fit(x_train,y_train)
pred_SGD = SGD.predict(x_test)
pred_train = SGD.predict(x_train)
print("R2_score:", r2_score(y_test, pred_SGD))
print("R2_score on training Data:", r2_score(y_train, pred_train)*100)
print("Mean Aboslute Error:", mean_absolute_error(y_test,pred_SGD))
print("Mean Squared Error:", mean_squared_error(y_test, pred_SGD))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, pred_SGD)))
# Out:
# R2_score: 0.9304878570586411
# R2_score on training Data: 89.91963168096558
# Mean Aboslute Error: 2.490058000143817
# Mean Squared Error: 8.353471597422068
# Root Mean Squared Error: 2.890237290850367

# %% [markdown]
# # Cross validation of the models

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(LR,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between cross validation score and R2 score at LinearRegression is:",(r2_score(y_test,pred_LR)- score.mean())*100)
# Out:
# [ 0.35678372 -0.97264702  0.64210197  0.73303244  0.7159174 ]
# 0.2950377003300811
# Difference between cross validation score and R2 score at LinearRegression is: 64.56866326207683

# %%
score1= cross_val_score(RFR,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between cross validation score and R2 score at RandomForestRegressor is:",(r2_score(y_test,pred_RFR)- score.mean())*100)
# Out:
# [ 0.14282023 -5.45424474  0.5216609   0.41201148  0.85887205]
# -0.7037760174499497
# Difference between cross validation score and R2 score at RandomForestRegressor is: 26.234000667628816

# %%
score3= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between cross validation score and R2 score at knn is:",(r2_score(y_test,pred_knn)- score.mean())*100)
# Out:
# [-0.28481818 -1.74684211  0.44160602  0.1677377   0.6307783 ]
# -0.1583076515383647
# Difference between cross validation score and R2 score at knn is: 26.48184739045602

# %%
score5= cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print("Difference between cross validation score and R2 score at lasso is:",(r2_score(y_test,pred_lasso)- score.mean())*100)
# Out:
# [ 0.74131037 -0.80501212  0.75601422  0.73913317  0.91574558]
# 0.4694382450031223
# Difference between cross validation score and R2 score at lasso is: 64.63728413542877

# %%
score6= cross_val_score(rd,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print("Difference between cross validation score and R2 score at Ridge is:",(r2_score(y_test,pred_rd)- score.mean())*100)
# Out:
# [ 0.49463    -0.93808345  0.67033268  0.91429406  0.7672934 ]
# 0.381693337916413
# Difference between cross validation score and R2 score at Ridge is: 65.44555868068962

# %%
score7= cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score7)
print(score7.mean())
print("Difference between cross validation score and R2 score at DecisionTreeRegressor is:",(r2_score(y_test,pred_dtr)- score.mean())*100)
# Out:
# [ -0.59886364 -10.27631579   0.32831451  -0.61147541   0.31603774]
# -2.1684605174136324
# Difference between cross validation score and R2 score at DecisionTreeRegressor is: -9.666087682484187

# %%
score8= cross_val_score(tr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print("Difference between cross validation score and R2 score at ExtraTreesRegressor is:",(r2_score(y_test,pred_tr)- score.mean())*100)
# Out:
# [ 0.10246989 -4.56187895  0.51513283  0.35621803  0.808102  ]
# -0.5559912384099281
# Difference between cross validation score and R2 score at ExtraTreesRegressor is: 20.484485565923478

# %%
score9= cross_val_score(xgb,x,y,cv=5,scoring='r2')
print(score9)
print(score9.mean())
print("Difference between cross validation score and R2 score at xgbregressor is:",(r2_score(y_test,pred_xgb)- score.mean())*100)
# Out:
# [ 0.14975894 -9.91335016  0.441041    0.16194326  0.71931624]
# -1.688258142982626
# Difference between cross validation score and R2 score at xgbregressor is: 26.478635825508505

# %%
score10= cross_val_score(SGD,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between cross validation score and R2 score at SGD is:",(r2_score(y_test,pred_SGD)- score.mean())*100)
# Out:
# [-0.28481818 -1.74684211  0.44160602  0.1677377   0.6307783 ]
# -0.1583076515383647
# Difference between cross validation score and R2 score at SGD is: 63.545015672855996

# %% [markdown]
# # conclusion

# %% [markdown]
# From the differnece between R2 score and cross validation score we can conclude that ExtraTreERegressor is our best fitted model.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'criterion':['squared_error', 'absoulte_error','poisson'],
             'max_depth':[0,10,20],
             'random_state':[10,50,100],
             'n_jobs':[-2,-1,1],
             'n_estimators':[10,100,150,200]}

# %%
GCV=GridSearchCV(ExtraTreesRegressor(),parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['squared_error', 'absoulte_error',
#                                        'poisson'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [10, 100, 150, 200],
#                          'n_jobs': [-2, -1, 1], 'random_state': [10, 50, 100]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 10,
#  'n_estimators': 100,
#  'n_jobs': -2,
#  'random_state': 10}

# %%
Final_model = ExtraTreesRegressor(criterion = 'poisson', max_depth= 10, n_estimators= 100,n_jobs= -2, random_state= 10)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print('R2_score:', r2_score(y_test, pred))
print("Mean_absolute_error:", mean_absolute_error(y_test,pred))
print("Mean Squared Error:", mean_squared_error(y_test,pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.5211795253749745
# Mean_absolute_error: 5.946296296296296
# Mean Squared Error: 57.5412160493827
# Root Mean Squared Error: 7.585592663027899

# %% [markdown]
# # so the best R2 score for final model is 52.11%

# %% [markdown]
# # Saving the model

# %%
#saving the model using.pkl
import joblib
joblib.dump(Final_model, "baseball.pkl")
# Out:
# ['baseball.pkl']

# %%
import pickle
filename='baseball.pkl'
pickle.dump(Final_model,open(filename,'wb'))

# %%
import pickle
loaded_model= pickle.load(open('baseball.pkl', 'rb'))
result= loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 52.117952537497445

# %%
conclusion= pd.DataFrame([loaded_model.predict(x_test)[:], y_test[:]], index=["Predicted", "Original"])
conclusion
# Out:
#               0       1      2      3      4          5      6      7      8
# Predicted  69.8   88.87  70.65  68.57  71.77  76.893333  71.95  88.96  82.46
# Original   78.0  100.00  68.00  63.00  74.00  79.000000  88.00  90.00  87.00

# %% [markdown]
# # Concluding Remarks

# %% [markdown]
# 1.We predicted the outcomes of MLB matches by collecting the match data of 30 teams in the 2014 season using different Regression Models.
#
# 2.The prediction accuracies of different models were then compared and choosed the best model to fit.
#
# 3.The prediction results indicated that ExtraTreeRegressor model achieved higher prediction accuracy according to the difference between cross validation score and R2 score
